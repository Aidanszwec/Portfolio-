# %% [markdown]
# ## Warehouse optimization
#
# Within this kernel we will analyse sales data of an UK online retailer. As storage area may be expensive and fast delivery on time is important to prevail over the competition we like to help the retailer by predicting daily amounts of sold products.

# %% [markdown]
# ## Table of contents
#
# **Caution - Everything is heavily under construction ;-)**
#
# ### [Get ready to take-off](#takeoff)
#
# 1. [Prepare to start](#load) (complete)
# 2. [Get familiar with the data](#intro) (complete)
# 3. [Get an initial feeling for the data by exploration](#feeling)
#     * [Missing values](#missing) (complete)
#     * [The time period](#timeperiod) (complete)
#     * [The invoice number](#invoiceno) (complete)
#     * [Stockcodes](#stockcodes) (complete)
#     * [Descriptions](#descriptions) (complete)
#     * [Customers](#customers)
#     * [Countries](#countries) (complete)
#     * [Unit Price](#unitprice)
#     * [Quantities](#quantities) (complete)
#     * [Revenues](#revenues)
#     * [Conclusion](#expconclusion)
# 4. [Focus on daily product sales](#daily)

# %% [markdown]
# # Get ready to take-off <a class="anchor" id="takeoff"></a>
#
# ## 1. Prepare to start <a class="anchor" id="load"></a>

# %%
conda update scipy
# Out:
# Channels:
#  - defaults
# Platform: osx-arm64
# Collecting package metadata (repodata.json): done
# Solving environment: done
#
# # All requested packages already installed.
#
#
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install GPy

# %%
git clone https://github.com/SheffieldML/GPyOpt.git
# Out:
#   Cell In[11], line 1
#     git clone https://github.com/SheffieldML/GPyOpt.git
#         ^
# SyntaxError: invalid syntax

# %%
import numpy as np 
import pandas as pd 
import matplotlib.pyplot as plt
# %matplotlib inline

import seaborn as sns
sns.set()

from catboost import CatBoostRegressor, Pool, cv
from catboost import MetricVisualizer

from sklearn.model_selection import TimeSeriesSplit
from sklearn.preprocessing import StandardScaler
from sklearn.cluster import KMeans

from scipy.stats import boxcox
from os import listdir

import warnings
warnings.filterwarnings("ignore", category=DeprecationWarning)
warnings.filterwarnings("ignore", category=UserWarning)
warnings.filterwarnings("ignore", category=RuntimeWarning)
warnings.filterwarnings("ignore", category=FutureWarning)

import shap
shap.initjs()
# Out:
# <div align='center'><img src='data:image/png;base64,...' /></div><script charset='utf-8'>/*! For license information please see bundle.js.LICENSE.txt */
# (()=>{var e={486:function(e,t,n){var r;e=n.nmd(e),function(){var a,i="Expected a function",o="__lodash_hash_undefined__",u="__lodash_placeholder__",l=32,s=128,c=1/0,f=9007199254740991,p=NaN,d=4294967295,h=[["ary",s],["bind",1],["bindKey",2],["curry",8],["curryRight",16],["flip",512],["partial",l],["partialRight",64],["rearg",256]],v="[object Arguments]",g="[object Array]",y="[object Boolean]",m="[object Date]",b="[object Error]",_="[object Function]",w="[object GeneratorFunction]",x="[object Map]",k="[object Number]",S="[object Object]",E="[object Promise]",C="[object RegExp]",T="[object Set]",M="[object String]",N="[object Symbol]",P="[object WeakMap]",z="[object ArrayBuffer]",L="[object DataView]",O="[object Float32Array]",A="[object Float64Array]",F="[object Int8Array]",D="[object Int16Array]",R="[object Int32Array]",j="[object Uint8Array]",U="[object Uint8ClampedArray]",I="[object Uint16Array]",$="[object Uint32Array]",B=/\b__p \+= '';/g,W=/\b(__p \+=) '' \+/g,V=/(__e\(.*?\)|\b__t\)) \+\n'';/g,H=/&(?:amp|lt|gt|quot|#39);/g,q=/[&<>"']/g,Q=RegExp(H.source),Y=RegExp(q.source),G=/<%-([\s\S]+?)%>/g,K=/<%([\s\S]+?)%>/g,Z=/<%=([\s\S]+?)%>/g,X=/\.|\[(?:[^[\]]*|(["'])(?:(?!\1)[^\\]|\\.)*?\1)\]/,J=/^\w*$/,ee=/[^.[\]]+|\[(?:(-?\d+(?:\.\d+)?)|(["'])((?:(?!\2)[^\\]|\\.)*?)\2)\]|(?=(?:\.|\[\])(?:\.|\[\]|$))/g,te=/[\\^$.*+?()[\]{}|]/g,ne=RegExp(te.source),re=/^\s+/,ae=/\s/,ie=/\{(?:\n\/\* \[wrapped with .+\] \*\/)?\n?/,oe=/\{\n\/\* \[wrapped with (.+)\] \*/,ue=/,? & /,le=/[^\x00-\x2f\x3a-\x40\x5b-\x60\x7b-\x7f]+/g,se=/[()=,{}\[\]\/\s]/,ce=/\\(\\)?/g,fe=/\$\{([^\\}]*(?:\\.[^\\}]*)*)\}/g,pe=/\w*$/,de=/^[-+]0x[0-9a-f]+$/i,he=/^0b[01]+$/i,ve=/^\[object .+?Constructor\]$/,ge=/^0o[0-7]+$/i,ye=/^(?:0|[1-9]\d*)$/,me=/[\xc0-\xd6\xd8-\xf6\xf8-\xff\u0100-\u017f]/g,be=/($^)/,_e=/['\n\r\u2028\u2029\\]/g,we="\\ud800-\\udfff",xe="\\u0300-\\u036f\\ufe20-\\ufe2f\\u20d0-\\u20ff",ke="\\u2700-\\u27bf",Se="a-z\\xdf-\\xf6\\xf8-\\xff",Ee="A-Z\\xc0-\\xd6\\xd8-\\xde",Ce="\\ufe0e\\ufe0f",Te="\\xac\\xb1\\xd7\\xf7\\x00-\\x2f\\x3a-\\x40\\x5b-\\x60\\x7b-\\xbf\\u2000-\\u206f \\t\\x0b\\f\\xa0\\ufeff\\n\\r\\u2028\\u2029\\u1680\\u180e\\u2000\\u2001\\u2002\\u2003\\u2004\\u2005\\u2006\\u2007\\u2008\\u2009\\u200a\\u202f\\u205f\\u3000",Me="["+we+"]",Ne="["+Te+"]",Pe="["+xe+"]",ze="\\d+",Le="["+ke+"]",Oe="["+Se+"]",Ae="[^"+we+Te+ze+ke+Se+Ee+"]",Fe="\\ud83c[\\udffb-\\udfff]",De="[^"+we+"]",Re="(?:\\ud83c[\\udde6-\\uddff]){2}",je="[\\ud800-\\udbff][\\udc00-\\udfff]",Ue="["+Ee+"]",Ie="\\u200d",$e="(?:"+Oe+"|"+Ae+")",Be="(?:"+Ue+"|"+Ae+")",We="(?:['’](?:d|ll|m|re|s|t|ve))?",Ve="(?:['’](?:D|LL|M|RE|S|T|VE))?",He="(?:"+Pe+"|"+Fe+")?",qe="["+Ce+"]?",Qe=qe+He+"(?:"+Ie+"(?:"+[De,Re,je].join("|")+")"+qe+He+")*",Ye="(?:"+[Le,Re,je].join("|")+")"+Qe,Ge="(?:"+[De+Pe+"?",Pe,Re,je,Me].join("|")+")",Ke=RegExp("['’]","g"),Ze=RegExp(Pe,"g"),Xe=RegExp(Fe+"(?="+Fe+")|"+Ge+Qe,"g"),Je=RegExp([Ue+"?"+Oe+"+"+We+"(?="+[Ne,Ue,"$"].join("|")+")",Be+"+"+Ve+"(?="+[Ne,Ue+$e,"$"].join("|")+")",Ue+"?"+$e+"+"+We,Ue+"+"+Ve,"\\d*(?:1ST|2ND|3RD|(?![123])\\dTH)(?=\\b|[a-z_])","\\d*(?:1st|2nd|3rd|(?![123])\\dth)(?=\\b|[A-Z_])",ze,Ye].join("|"),"g"),et=RegExp("["+Ie+we+xe+Ce+"]"),tt=/[a-z][A-Z]|[A-Z]{2}[a-z]|[0-9][a-zA-Z]|[a-zA-Z][0-9]|[^a-zA-Z0-9 ]/,nt=["Array","Buffer","DataView","Date","Error","Float32Array","Float64Array","Function","Int8Array","Int16Array","Int32Array","Map","Math","Object","Promise","RegExp","Set","String","Symbol","TypeError","Uint8Array","Uint8ClampedArray","Uint16Array","Uint32Array","WeakMap","_","clearTimeout","isFinite","parseInt","setTimeout"],rt=-1,at={};at[O]=at[A]=at[F]=at[D]=at[R]=at[j]=at[U]=at[I]=at[$]=!0,at[v]=at[g]=at[z]=at[y]=at[L]=at[m]=at[b]=at[_]=at[x]=at[k]=at[S]=at[C]=at[T]=at[M]=at[P]=!1;var it={};it[v]=it[g]=it[z]=it[L]=it[y]=it[m]=it[O]=it[A]=it[F]=it[D]=it[R]=it[x]=it[k]=it[S]=it[C]=it[T]=it[M]=it[N]=it[j]=it[U]=it[I]=it[$]=!0,it[b]=it[_]=it[P]=!1;var ot={"\\":"\\","'":"'","\n":"n","\r":"r","\u2028":"u2028","\u2029":"u2029"},ut=parseFloat,lt=parseInt,st="object"==typ ...

# %%
data = pd.read_csv("data.csv", encoding="ISO-8859-1", dtype={'CustomerID': str})
data.shape
# Out:
# (541909, 8)

# %% [markdown]
# The data has 541909 entries and 8 variables.

# %% [markdown]
# ## 2. Get familiar with the data <a class="anchor" id="intro"></a>

# %%
data.head()
# Out:
#   InvoiceNo StockCode                          Description  Quantity  \
# 0    536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1    536365     71053                  WHITE METAL LANTERN         6
# 2    536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3    536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4    536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
#
#       InvoiceDate  UnitPrice CustomerID         Country
# 0  12/1/2010 8:26       2.55      17850  United Kingdom
# 1  12/1/2010 8:26       3.39      17850  United Kingdom
# 2  12/1/2010 8:26       2.75      17850  United Kingdom
# 3  12/1/2010 8:26       3.39      17850  United Kingdom
# 4  12/1/2010 8:26       3.39      17850  United Kingdom

# %% [markdown]
# We can see that the datafile has information given for **each single transaction**. Take a look at the InvoiceNo and the CustomerID of the first entries. Here we can see that **one customer with ID 17850 of the United Kingdom made a single order that has the InvoideNo 536365**. The customer ordered **several products with different stockcodes, descriptions, unit prices and quantities**. In addition we can see that the InvoiceDate was the same for these products.

# %% [markdown]
# ## 3. Get an initial feeling for the data by exploration <a class="anchor" id="feeling"></a>

# %% [markdown]
# ### Missing values <a class="anchor" id="missing"></a>

# %% [markdown]
# How many % of missing values do we have for each feature?

# %%
missing_percentage = data.isnull().sum() / data.shape[0] * 100
missing_percentage
# Out:
# InvoiceNo       0.000000
# StockCode       0.000000
# Description     0.268311
# Quantity        0.000000
# InvoiceDate     0.000000
# UnitPrice       0.000000
# CustomerID     24.926694
# Country         0.000000
# dtype: float64

# %% [markdown]
# Almost 25 % of the customers are unknown! That's very strange. In addition we have 0.2 % of missing descriptions. This looks dirty. Let's gain a further impression by considering some examples.

# %% [markdown]
# **Missing descriptions**

# %%
data[data.Description.isnull()].head()
# Out:
#      InvoiceNo StockCode Description  Quantity      InvoiceDate  UnitPrice  \
# 622     536414     22139         NaN        56  12/1/2010 11:52        0.0
# 1970    536545     21134         NaN         1  12/1/2010 14:32        0.0
# 1971    536546     22145         NaN         1  12/1/2010 14:33        0.0
# 1972    536547     37509         NaN         1  12/1/2010 14:33        0.0
# 1987    536549    85226A         NaN         1  12/1/2010 14:34        0.0
#
#      CustomerID         Country
# 622         NaN  United Kingdom
# 1970        NaN  United Kingdom
# 1971        NaN  United Kingdom
# 1972        NaN  United Kingdom
# 1987        NaN  United Kingdom

# %% [markdown]
# How often do we miss the customer as well?

# %%
data[data.Description.isnull()].CustomerID.isnull().value_counts()
# Out:
# True    1454
# Name: CustomerID, dtype: int64

# %% [markdown]
# And the unit price?

# %%
data[data.Description.isnull()].UnitPrice.value_counts()
# Out:
# 0.0    1454
# Name: UnitPrice, dtype: int64

# %% [markdown]
# In **cases of missing descriptions we always miss the customer and the unit price as well**. Why does the retailer records such kind of entries without a further description? It seems that there is no sophisticated procedure how to deal with and record such kind of transactions. This is already a hint that **we could expect strange entries in our data and that it can be difficult to detect them**!

# %% [markdown]
# **Missing Customer IDs**

# %%
data[data.CustomerID.isnull()].head()
# Out:
#      InvoiceNo StockCode                      Description  Quantity  \
# 622     536414     22139                              NaN        56
# 1443    536544     21773  DECORATIVE ROSE BATHROOM BOTTLE         1
# 1444    536544     21774  DECORATIVE CATS BATHROOM BOTTLE         2
# 1445    536544     21786               POLKADOT RAIN HAT          4
# 1446    536544     21787            RAIN PONCHO RETROSPOT         2
#
#           InvoiceDate  UnitPrice CustomerID         Country
# 622   12/1/2010 11:52       0.00        NaN  United Kingdom
# 1443  12/1/2010 14:32       2.51        NaN  United Kingdom
# 1444  12/1/2010 14:32       2.51        NaN  United Kingdom
# 1445  12/1/2010 14:32       0.85        NaN  United Kingdom
# 1446  12/1/2010 14:32       1.66        NaN  United Kingdom

# %%
data.loc[data.CustomerID.isnull(), ["UnitPrice", "Quantity"]].describe()
# Out:
#            UnitPrice       Quantity
# count  135080.000000  135080.000000
# mean        8.076577       1.995573
# std       151.900816      66.696153
# min    -11062.060000   -9600.000000
# 25%         1.630000       1.000000
# 50%         3.290000       1.000000
# 75%         5.450000       3.000000
# max     17836.460000    5568.000000

# %% [markdown]
# That's bad as well. **The price and the quantities of entries without a customer ID can show extreme outliers**. As we might want to create features later on that are based on historical prices and sold quantities, this is very disruptive. Our first **advice for the retailer is to setup strategies for transactions that are somehow faulty or special**. And the question remains: Why is it possible for a transaction to be without a customer ID. Perhaps you can purchase as a quest but then it would of a good and clean style to plugin a special ID that indicates that this one is a guest. Ok, next one: Do we have hidden nan-values in Descriptions? To find it out, let's create a new feature that hold descriptions in lowercase:

# %% [markdown]
# **Hidden missing descriptions**
#
# Can we find "nan"-Strings?

# %%
data.loc[data.Description.isnull()==False, "lowercase_descriptions"] = data.loc[
    data.Description.isnull()==False,"Description"
].apply(lambda l: l.lower())

data.lowercase_descriptions.dropna().apply(
    lambda l: np.where("nan" in l, True, False)
).value_counts()
# Out:
# False    539724
# True        731
# Name: lowercase_descriptions, dtype: int64

# %% [markdown]
# Can we find empty ""-strings?

# %%
data.lowercase_descriptions.dropna().apply(
    lambda l: np.where("" == l, True, False)
).value_counts()
# Out:
# False    540455
# Name: lowercase_descriptions, dtype: int64

# %% [markdown]
# We found **additional, hidden nan-values that show a string "nan" instead of a nan-value**. Let's transform them to NaN:

# %%
data.loc[data.lowercase_descriptions.isnull()==False, "lowercase_descriptions"] = data.loc[
    data.lowercase_descriptions.isnull()==False, "lowercase_descriptions"
].apply(lambda l: np.where("nan" in l, None, l))

# %% [markdown]
# As we don't know why customers or descriptions are missing and we have seen strange outliers in quantities and prices as well as zero-prices, **let's play safe and drop all of these occurences**.

# %%
data = data.loc[(data.CustomerID.isnull()==False) & (data.lowercase_descriptions.isnull()==False)].copy()

# %% [markdown]
# Just to be sure: Is there a missing value left?

# %%
data.isnull().sum().sum()
# Out:
# 0

# %% [markdown]
# ### The Time period <a class="anchor" id="timeperiod"></a>
#
# How long is the period in days?

# %%
data["InvoiceDate"] = pd.to_datetime(data.InvoiceDate, cache=True)

data.InvoiceDate.max() - data.InvoiceDate.min()
# Out:
# Timedelta('373 days 04:24:00')

# %%
print("Datafile starts with timepoint {}".format(data.InvoiceDate.min()))
print("Datafile ends with timepoint {}".format(data.InvoiceDate.max()))
# Out:
# Datafile starts with timepoint 2010-12-01 08:26:00
# Datafile ends with timepoint 2011-12-09 12:50:00

# %% [markdown]
# ### The invoice number <a class="anchor" id="invoiceno"></a>

# %% [markdown]
# How many different invoice numbers do we have?

# %%
data.InvoiceNo.nunique()
# Out:
# 22186

# %% [markdown]
# In the data description we can find that a cancelled transactions starts with a "C" in front of it. Let's create a feature to easily filter out these cases:

# %%
data["IsCancelled"]=np.where(data.InvoiceNo.apply(lambda l: l[0]=="C"), True, False)
data.IsCancelled.value_counts() / data.shape[0] * 100
# Out:
# False    97.81007
# True      2.18993
# Name: IsCancelled, dtype: float64

# %% [markdown]
# 2,2 % of all entries are cancellations.

# %%
data.loc[data.IsCancelled==True].describe()
# Out:
#            Quantity     UnitPrice
# count   8896.000000   8896.000000
# mean     -30.882981     18.862815
# std     1170.746458    444.590459
# min   -80995.000000      0.010000
# 25%       -6.000000      1.450000
# 50%       -2.000000      2.950000
# 75%       -1.000000      4.950000
# max       -1.000000  38970.000000

# %% [markdown]
# **All cancellations have negative quantites but positive, non-zero unit prices**. Given this data we are not easily able to understand why a customer made a return and it's very difficult to predict such cases as there could be several, hidden reasons why a cancellation was done. Let's drop them:

# %%
data = data.loc[data.IsCancelled==False].copy()
data = data.drop("IsCancelled", axis=1)

# %% [markdown]
# ### Stockcodes <a class="anchor" id="stockcodes"></a>

# %% [markdown]
# How many unique stockcodes do we have?

# %%
data.StockCode.nunique()
# Out:
# 3663

# %% [markdown]
# Which codes are most common?

# %%
stockcode_counts = data.StockCode.value_counts().sort_values(ascending=False)

# Create subplots
fig, ax = plt.subplots(2, 1, figsize=(20, 15))

# Barplot for the most common stockcodes
sns.barplot(x=stockcode_counts.iloc[0:20].index,
            y=stockcode_counts.iloc[0:20].values,
            ax=ax[0], palette="Oranges_r")

# Set labels and title for the first subplot
ax[0].set_ylabel("Counts")
ax[0].set_xlabel("Stockcode")
ax[0].set_title("Which stockcodes are most common?")

# Distribution plot for the percentage of data with each stockcode
sns.distplot(np.round(stockcode_counts / data.shape[0] * 100, 2),
             kde=False,
             bins=20,
             ax=ax[1], color="Orange")

# Set labels and title for the second subplot
ax[1].set_title("How seldom are stockcodes?")
ax[1].set_xlabel("% of data with this stockcode")
ax[1].set_ylabel("Frequency")

# Show the plots
plt.show()

# %% [markdown]
# * Do you the the **POST** in the most common stockcode counts?! **That's a strange one!** Hence we could expect strange occurences not only in the descriptions and customerIDs but also in the stockcode. OHOHOH! It's code is shorter than the others as well as not numeric.
# * Most stockcodes are very seldom. This indicates that the **retailer sells many different products** and that there is no strong secialization of a specific stockcode. Nevertheless we have to be careful as this must not mean that the retailer is not specialized given a specific product type. The stockcode could be a very detailed indicator that does not yield information of the type, for example water bottles may have very different variants in color, name and shapes but they are all water bottles.

# %% [markdown]
# Let's count the number of numeric chars in and the length of the stockcode:

# %%
def count_numeric_chars(l):
    return sum(1 for c in l if c.isdigit())

data["StockCodeLength"] = data.StockCode.apply(lambda l: len(l))
data["nNumericStockCode"] = data.StockCode.apply(lambda l: count_numeric_chars(l))

# %%
fig, ax = plt.subplots(1,2,figsize=(20,5))
sns.countplot(data["StockCodeLength"], palette="Oranges_r", ax=ax[0])
sns.countplot(data["nNumericStockCode"], palette="Oranges_r", ax=ax[1])
ax[0].set_xlabel("Length of stockcode")
ax[1].set_xlabel("Number of numeric chars in the stockcode");

# %% [markdown]
# Even though the majority of samples has a stockcode that consists of 5 numeric chars, we can see that there are other occurences as well. The length can vary between 1 and 12 and there are stockcodes with no numeric chars at all!

# %%
data.loc[data.nNumericStockCode < 5].lowercase_descriptions.value_counts()
# Out:
# postage                       1099
# manual                         290
# carriage                       133
# dotcom postage                  16
# bank charges                    12
# pads to match all cushions       4
# Name: lowercase_descriptions, dtype: int64

# %% [markdown]
# Ihh, again something that we don't want to predict. Again this indicates that the retailer does not speparate well between special kind of transactions and valid customer-retailer transactions. Let's drop all of these occurences:

# %%
data = data.loc[(data.nNumericStockCode == 5) & (data.StockCodeLength==5)].copy()
data.StockCode.nunique()
# Out:
# 2783

# %%
data = data.drop(["nNumericStockCode", "StockCodeLength"], axis=1)

# %% [markdown]
# ### Descriptions <a class="anchor" id="descriptions"></a>
#
# How many unique descriptions do we have?

# %%
data.Description.nunique()
# Out:
# 2983

# %% [markdown]
# And which are most common?

# %%
description_counts = data.Description.value_counts().sort_values(ascending=False).iloc[0:30]
plt.figure(figsize=(20,5))
sns.barplot(x=description_counts.index, y=description_counts.values, palette="Blues_r")
plt.ylabel("Counts")
plt.title("Which product descriptions are most common?");
plt.xticks(rotation=90);

# %% [markdown]
# Ok, we can see that **some descriptions correspond to a similar product type**. Do you see the multiple occurences of lunch bags? We often have **color information about the product** as well. Furthermore the most common descriptions seem to confirm that **the retailer sells various different kinds of products**. All descriptions seem to consist of **uppercase chars**. Ok, now let's do some addtional analysis on the descriptions by counting the length and the number of lowercase chars.

# %%
def count_lower_chars(l):
    return sum(1 for c in l if c.islower())

# %%
data["DescriptionLength"] = data.Description.apply(lambda l: len(l))
data["LowCharsInDescription"] = data.Description.apply(lambda l: count_lower_chars(l))

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd

# Convert to Series if not already
description_length_series = pd.Series(data.DescriptionLength)
low_chars_series = pd.Series(data.LowCharsInDescription)

# Create subplots
fig, ax = plt.subplots(1, 2, figsize=(20, 5))

# Countplot for DescriptionLength
sns.countplot(x=description_length_series, ax=ax[0], color="Purple")

# Countplot for LowCharsInDescription with a logarithmic scale
sns.countplot(x=low_chars_series, ax=ax[1], color="Purple")
ax[1].set_yscale("log")  # Set y-axis to logarithmic scale

# Show the plots
plt.show()

# %% [markdown]
# Oh, great! **Almost all descriptions do not have a lowercase chars, but we have found exceptional cases!**

# %%
lowchar_counts = data.loc[data.LowCharsInDescription > 0].Description.value_counts()

plt.figure(figsize=(15,3))
sns.barplot(x=lowchar_counts.index, y=lowchar_counts.values, palette="Purples_r")
plt.xticks(rotation=90);

# %% [markdown]
# **Next day carriage and high resolution image are strange!** Let's compute the fraction of lower with respect to uppercase letters:

# %%
def count_upper_chars(l):
    return sum(1 for c in l if c.isupper())

data["UpCharsInDescription"] = data.Description.apply(lambda l: count_upper_chars(l))

# %%
data.UpCharsInDescription.describe()
# Out:
# count    362522.000000
# mean         22.572291
# std           4.354845
# min           3.000000
# 25%          20.000000
# 50%          23.000000
# 75%          26.000000
# max          32.000000
# Name: UpCharsInDescription, dtype: float64

# %%
data.loc[data.UpCharsInDescription <=5].Description.value_counts()
# Out:
# Next Day Carriage        79
# High Resolution Image     3
# Name: Description, dtype: int64

# %% [markdown]
# It's strange that they differ from the others. Let's drop them:

# %%
data = data.loc[data.UpCharsInDescription > 5].copy()

# %% [markdown]
# And what about the descriptions with a length below 14?

# %%
dlength_counts = data.loc[data.DescriptionLength < 14].Description.value_counts()

plt.figure(figsize=(20,5))
sns.barplot(x = dlength_counts.index, y = dlength_counts.values, palette="Reds_r")
plt.xticks(rotation=90);

# %% [markdown]
# Ok, descriptions with small length look valid and we should not drop them. Ok, now let's see how many unique stock codes do we have and how many unique descriptions?

# %%
data.StockCode.nunique()
# Out:
# 2781

# %%
data.Description.nunique()
# Out:
# 2981

# %% [markdown]
# We still have more descriptions than stockcodes and we should continue to find out why they differ.

# %%
data.groupby("StockCode").Description.nunique().sort_values(ascending=False).iloc[0:10]
# Out:
# StockCode
# 23236    4
# 23196    4
# 23413    3
# 23244    3
# 23126    3
# 23203    3
# 23209    3
# 23366    3
# 23131    3
# 23535    3
# Name: Description, dtype: int64

# %% [markdown]
# Wow, we still have stockcodes with multiple descriptions. Let's look at an example:

# %%
data.loc[data.StockCode == "23244"].Description.value_counts()
# Out:
# ROUND STORAGE TIN VINTAGE LEAF    96
# STORAGE TIN VINTAGE LEAF           7
# CANNISTER VINTAGE LEAF DESIGN      2
# Name: Description, dtype: int64

# %% [markdown]
# Ok, browsing through the cases we can see that stockcodes are sometimes named a bit differently due to missing or changed words or typing errors. None the less they look ok and we can continue.

# %% [markdown]
# ### Customers <a class="anchor" id="customers"></a>

# %%
data.CustomerID.nunique()
# Out:
# 4315

# %%
customer_counts = data.CustomerID.value_counts().sort_values(ascending=False).iloc[0:20] 
plt.figure(figsize=(20,5))
sns.barplot(x = customer_counts.index, y = customer_counts.values, order=customer_counts.index)
plt.ylabel("Counts")
plt.xlabel("CustomerID")
plt.title("Which customers are most common?");
#plt.xticks(rotation=90);

# %% [markdown]
# ### Countries <a class="anchor" id="countries"></a>
#
# How many unique countries are delivered by the retailer?

# %%
data.Country.nunique()
# Out:
# 37

# %% [markdown]
# And which ones are most common?

# %%
country_counts = data.Country.value_counts().sort_values(ascending=False).iloc[0:20]
plt.figure(figsize=(20,5))
sns.barplot(x=country_counts.index, y=country_counts.values, palette="Greens_r")
plt.ylabel("Counts")
plt.title("Which countries made the most transactions?");
plt.xticks(rotation=90);
plt.yscale("log")

# %% [markdown]
# We can see that the retailer sells almost all products in the UK, followed by many european countries. How many percentage of entries are inside UK?

# %%
data.loc[data.Country=="United Kingdom"].shape[0] / data.shape[0] * 100
# Out:
# 89.10192031784572

# %% [markdown]
# Let's create a feature to indicate inside or outside of the UK:

# %%
data["UK"] = np.where(data.Country == "United Kingdom", 1, 0)

# %% [markdown]
# ### Unit Price <a class="anchor" id="unitprice"></a>

# %%
data.UnitPrice.describe()
# Out:
# count    362440.000000
# mean          2.885355
# std           4.361812
# min           0.000000
# 25%           1.250000
# 50%           1.790000
# 75%           3.750000
# max         649.500000
# Name: UnitPrice, dtype: float64

# %% [markdown]
# Again, we have strange occurences: zero unit prices!

# %%
data.loc[data.UnitPrice == 0].sort_values(by="Quantity", ascending=False).head()
# Out:
#        InvoiceNo StockCode                          Description  Quantity  \
# 502122    578841     84826       ASSTD DESIGN 3D PAPER STICKERS     12540
# 298054    562973     23157           SET OF 6 NATIVITY MAGNETS        240
# 436428    574138     23234        BISCUIT TIN VINTAGE CHRISTMAS       216
# 314746    564651     23268  SET OF 2 CERAMIC CHRISTMAS REINDEER       192
# 314748    564651     21786                   POLKADOT RAIN HAT        144
#
#                InvoiceDate  UnitPrice CustomerID         Country  \
# 502122 2011-11-25 15:57:00        0.0      13256  United Kingdom
# 298054 2011-08-11 11:42:00        0.0      14911            EIRE
# 436428 2011-11-03 11:26:00        0.0      12415       Australia
# 314746 2011-08-26 14:19:00        0.0      14646     Netherlands
# 314748 2011-08-26 14:19:00        0.0      14646     Netherlands
#
#                      lowercase_descriptions  DescriptionLength  \
# 502122       asstd design 3d paper stickers                 30
# 298054           set of 6 nativity magnets                  26
# 436428        biscuit tin vintage christmas                 29
# 314746  set of 2 ceramic christmas reindeer                 35
# 314748                   polkadot rain hat                  18
#
#         LowCharsInDescription  UpCharsInDescription  UK
# 502122                      0                    25   1
# 298054                      0                    20   0
# 436428                      0                    26   0
# 314746                      0                    29   0
# 314748                      0                    15   0

# %% [markdown]
# That's not good again. It's not obvious if they are gifts to customers or not :-( Let's drop them:

# %%
data = data.loc[data.UnitPrice > 0].copy()

# %%
fig, ax = plt.subplots(1,2,figsize=(20,5))
sns.distplot(data.UnitPrice, ax=ax[0], kde=False, color="red")
sns.distplot(np.log(data.UnitPrice), ax=ax[1], bins=20, color="tomato", kde=False)
ax[1].set_xlabel("Log-Unit-Price");

# %%
np.exp(-2)
# Out:
# 0.1353352832366127

# %%
np.exp(3)
# Out:
# 20.085536923187668

# %%
np.quantile(data.UnitPrice, 0.95)
# Out:
# 8.5

# %% [markdown]
# Let's focus transactions with prices that fall into this range as we don't want to make predictions for very seldom products with high prices. Starting easy is always good!

# %%
data = data.loc[(data.UnitPrice > 0.1) & (data.UnitPrice < 20)].copy()

# %% [markdown]
# ### Quantities <a class="anchor" id="quantities"></a>
#
# Ok, the most important one - the target. Let's take a look at its distribution:

# %%
data.Quantity.describe()
# Out:
# count    361608.000000
# mean         13.024112
# std         187.566510
# min           1.000000
# 25%           2.000000
# 50%           6.000000
# 75%          12.000000
# max       80995.000000
# Name: Quantity, dtype: float64

# %% [markdown]
# Ok, most products are sold in quantities from 1 to 12. But, we have extreme, unrealistic outliers again:

# %%
fig, ax = plt.subplots(1,2,figsize=(20,5))
sns.distplot(data.Quantity, ax=ax[0], kde=False, color="limegreen");
sns.distplot(np.log(data.Quantity), ax=ax[1], bins=20, kde=False, color="limegreen");
ax[0].set_title("Quantity distribution")
ax[0].set_yscale("log")
ax[1].set_title("Log-Quantity distribution")
ax[1].set_xlabel("Natural-Log Quantity");

# %% [markdown]
# As you can see by the log-transformed distribution it would make sense to make a cut at:

# %%
np.exp(4)
# Out:
# 54.598150033144236

# %%
np.quantile(data.Quantity, 0.95)
# Out:
# 36.0

# %% [markdown]
# In this case we would still cover more than 95 % of the data!

# %%
data = data.loc[data.Quantity < 55].copy()

# %% [markdown]
# ### Revenues <a class="anchor" id="revenues"></a>

# %% [markdown]
# ### Conclusion <a class="anchor" id="expconclusion"></a>

# %% [markdown]
# ## Focus on daily product sales <a class="anchor" id="daily"></a>
#
# As we like to predict the daily amount of product sales, we need to compute a daily aggregation of this data. For this purpose we need to extract temporal features out of the InvoiceDate. In addition we can compute the revenue gained by a transaction using the unit price and the quantity:

# %%
data["Revenue"] = data.Quantity * data.UnitPrice

data["Year"] = data.InvoiceDate.dt.year
data["Quarter"] = data.InvoiceDate.dt.quarter
data["Month"] = data.InvoiceDate.dt.month
data["Week"] = data.InvoiceDate.dt.week
data["Weekday"] = data.InvoiceDate.dt.weekday
data["Day"] = data.InvoiceDate.dt.day
data["Dayofyear"] = data.InvoiceDate.dt.dayofyear
data["Date"] = pd.to_datetime(data[['Year', 'Month', 'Day']])

# %% [markdown]
# As the key task of this kernel is to predict the amount of products sold per day, we can sum up the daily quantities per product stockcode :

# %%
grouped_features = ["Date", "Year", "Quarter","Month", "Week", "Weekday", "Dayofyear", "Day",
                    "StockCode"]

# %% [markdown]
# This way we loose information abount customers, countries and price information but we will recover it later on during this kernel. Besides the quantities let's aggregate the revenues as well:

# %%
daily_data = pd.DataFrame(data.groupby(grouped_features).Quantity.sum(),
                          columns=["Quantity"])
daily_data["Revenue"] = data.groupby(grouped_features).Revenue.sum()
daily_data = daily_data.reset_index()
daily_data.head(5)
# Out:
#         Date  Year  Quarter  Month  Week  Weekday  Dayofyear  Day StockCode  \
# 0 2010-12-01  2010        4     12    48        2        335    1     10002
# 1 2010-12-01  2010        4     12    48        2        335    1     10125
# 2 2010-12-01  2010        4     12    48        2        335    1     10133
# 3 2010-12-01  2010        4     12    48        2        335    1     16014
# 4 2010-12-01  2010        4     12    48        2        335    1     16016
#
#    Quantity  Revenue
# 0        60    51.00
# 1         2     1.70
# 2         5     4.25
# 3        10     4.20
# 4        10     8.50

# %% [markdown]
# #### How are the quantities and revenues distributed?

# %%
daily_data.loc[:, ["Quantity", "Revenue"]].describe()
# Out:
#             Quantity        Revenue
# count  195853.000000  195853.000000
# mean       14.964244      28.181114
# std        18.809496      43.938183
# min         1.000000       0.120000
# 25%         3.000000       6.950000
# 50%         9.000000      15.300000
# 75%        20.000000      30.600000
# max       411.000000    1266.300000

# %% [markdown]
# As we can see by the min and max values the **target variable shows extreme outliers**.  If we would like to use it as targets, we **should exclude them as they will mislead our validation. As I like to use early stopping this will directly influence training of predictive models as well**.

# %%
low_quantity = daily_data.Quantity.quantile(0.01)
high_quantity = daily_data.Quantity.quantile(0.99)
print((low_quantity, high_quantity))
# Out:
# (1.0, 88.48000000001048)

# %%
low_revenue = daily_data.Revenue.quantile(0.01)
high_revenue = daily_data.Revenue.quantile(0.99)
print((low_revenue, high_revenue))
# Out:
# (0.78, 204.0)

# %% [markdown]
# Let's **only use target ranges data that are occupied by  90 % of the data entries**. This is a first and easy strategy to exclude heavy outliers but we should always be aware of the fact that we have lost some information given by the remaining % we have excluded. It could be nice and useful in general to understand and analyse what has caused these outliers.

# %%
samples = daily_data.shape[0]

# %%
daily_data = daily_data.loc[
    (daily_data.Quantity >= low_quantity) & (daily_data.Quantity <= high_quantity)]
daily_data = daily_data.loc[
    (daily_data.Revenue >= low_revenue) & (daily_data.Revenue <= high_revenue)]

# %% [markdown]
# How much entries have we lost?

# %%
samples - daily_data.shape[0]
# Out:
# 5258

# %% [markdown]
# Let's take a look at the remaining distributions of daily quantities:

# %%
fig, ax = plt.subplots(1,2,figsize=(20,5))
sns.distplot(daily_data.Quantity.values, kde=True, ax=ax[0], color="Orange", bins=30);
sns.distplot(np.log(daily_data.Quantity.values), kde=True, ax=ax[1], color="Orange", bins=30);
ax[0].set_xlabel("Number of daily product sales");
ax[0].set_ylabel("Frequency");
ax[0].set_title("How many products are sold per day?");

# %% [markdown]
# We can see that the distributions are **right skewed. Lower values are more common**. In addition the daily sales quantities seem to be **multimodal**. A daily sale of 1 is common as well as a quantity of 12 and 24. This pattern is very interesting and leads to the conclusion that quantities are often divisible by 2 or 3. In a nutshell we can say that specific products are often bought as single quantites or in a small bunch.

# %% [markdown]
# ## How to predict daily product sales? <a class="anchor" id="model"></a>
#
# In this kernel I like to use [catboost ](https://catboost.ai/) as predictive model. The prediction of daily quantities and revenues are both regression tasks and consequently I will use the catboost regressor. The loss and metric I like to use is the [root mean square error](https://en.wikipedia.org/wiki/Root-mean-square_deviation) (RMSE):
#
# $$ E = \sqrt{ \frac{1}{N}\sum_{n=1}^{N} (t_{n} - y_{n})^{2}}$$
#
# It computes the error between the target value $t_{n}$ and the predicted value $y_{n}$ per sample, takes the square to make sure that both, positive and negative deviations, contribute to the sum the same way. Then the mean is taken by dividing with the total amount $N$ of samples (entries) in the data. And finally to obtain an impression of the error for single predictions, the root is taken. What should we keep in mind when working with this loss and metric function? :-) It's heavily influenced by outliers! **If we have some predictions that are far away from the targets, they will guide the mean towards higher values as well. Hence it could be that we will make nice predictions for a majority of samples but the RMSE is still high due to high errors for a minority of samples**.

# %% [markdown]
# ### Validation strategy
#
# As the **data covers only one year and we have a high increase of sold products during pre-christmas period**, we need to select validation data carefully. I will start with validation data that covers at least 8 full weeks (+ remaining days). After generating new features by exploring the data, I will use a sliding window time series validation that should help us to understand if the model is able to solve the prediction task during both times: pre-christmas season and non-christmas season.

# %% [markdown]
# ### Catboost family and hyperparameter class <a class="anchor" id="classes"></a>
#
# To easily generate new models and compare results between them I wrote some classes:

# %% [markdown]
# **Hyperparameter Class**
#
# This class holds all important hyperparameters we have to set before training like the loss function, the evaluation metric, the max depth of trees, the number of max number of trees (iterations) and the l2_leaf_reg for regularization to avoid overfitting.

# %%
class CatHyperparameter:
    
    def __init__(self,
                 loss="RMSE",
                 metric="RMSE",
                 iterations=1000,
                 max_depth=4,
                 l2_leaf_reg=3,
                 #learning_rate=0.5,
                 seed=0):
        self.loss = loss,
        self.metric = metric,
        self.max_depth = max_depth,
        self.l2_leaf_reg = l2_leaf_reg,
        #self.learning_rate = learning_rate,
        self.iterations=iterations
        self.seed = seed

# %% [markdown]
# **Catmodel class**
#
# This model obtains a train & validation pool as data or pandas dataframes for features X and targets y together with a week. It's the first week of our validation data and all other weeks above are used as well. It trains the model and can show learning process as well as feature importances and some figures for result analysis. It's the fastest choice you can make for playing around.

# %%
class Catmodel:
    
    def __init__(self, name, params):
        self.name = name
        self.params = params
    
    def set_data_pool(self, train_pool, val_pool):
        self.train_pool = train_pool
        self.val_pool = val_pool
    
    def set_data(self, X, y, week):
        cat_features_idx = np.where(X.dtypes != np.float)[0]
        x_train, self.x_val = X.loc[X.Week < week], X.loc[X.Week >= week]
        y_train, self.y_val = y.loc[X.Week < week], y.loc[X.Week >= week]
        self.train_pool = Pool(x_train, y_train, cat_features=cat_features_idx)
        self.val_pool = Pool(self.x_val, self.y_val, cat_features=cat_features_idx)
    
    def prepare_model(self):
        self.model = CatBoostRegressor(
                loss_function = self.params.loss[0],
                random_seed = self.params.seed,
                logging_level = 'Silent',
                iterations = self.params.iterations,
                max_depth = self.params.max_depth[0],
                #learning_rate = self.params.learning_rate[0],
                l2_leaf_reg = self.params.l2_leaf_reg[0],
                od_type='Iter',
                od_wait=40,
                train_dir=self.name,
                has_time=True
            )
    
    def learn(self, plot=False):
        self.prepare_model()
        self.model.fit(self.train_pool, eval_set=self.val_pool, plot=plot);
        print("{}, early-stopped model tree count {}".format(
            self.name, self.model.tree_count_
        ))
    
    def score(self):
        return self.model.score(self.val_pool)
    
    def show_importances(self, kind="bar"):
        explainer = shap.TreeExplainer(self.model)
        shap_values = explainer.shap_values(self.val_pool)
        if kind=="bar":
            return shap.summary_plot(shap_values, self.x_val, plot_type="bar")
        return shap.summary_plot(shap_values, self.x_val)
    
    def get_val_results(self):
        self.results = pd.DataFrame(self.y_val)
        self.results["prediction"] = self.predict(self.x_val)
        self.results["error"] = np.abs(
            self.results[self.results.columns.values[0]].values - self.results.prediction)
        self.results["Month"] = self.x_val.Month
        self.results["SquaredError"] = self.results.error.apply(lambda l: np.power(l, 2))
    
    def show_val_results(self):
        self.get_val_results()
        fig, ax = plt.subplots(1,2,figsize=(20,5))
        sns.distplot(self.results.error, ax=ax[0])
        ax[0].set_xlabel("Single absolute error")
        ax[0].set_ylabel("Density")
        self.median_absolute_error = np.median(self.results.error)
        print("Median absolute error: {}".format(self.median_absolute_error))
        ax[0].axvline(self.median_absolute_error, c="black")
        ax[1].scatter(self.results.prediction.values,
                      self.results[self.results.columns[0]].values,
                      c=self.results.error, cmap="RdYlBu_r", s=1)
        ax[1].set_xlabel("Prediction")
        ax[1].set_ylabel("Target")
        return ax
    
    def get_monthly_RMSE(self):
        return self.results.groupby("Month").SquaredError.mean().apply(lambda l: np.sqrt(l))
        
    def predict(self, x):
        return self.model.predict(x)
    
    def get_dependence_plot(self, feature1, feature2=None):
        explainer = shap.TreeExplainer(self.model)
        shap_values = explainer.shap_values(self.val_pool)
        if feature2 is None:
            return shap.dependence_plot(
                feature1,
                shap_values,
                self.x_val,
            )
        else:
            return shap.dependence_plot(
                feature1,
                shap_values,
                self.x_val,
                interaction_index=feature2
            )

# %% [markdown]
# **Hyperparameter-Search class**
#
# This is a class for hyperparameter search that uses Bayesian Optimization and Gaussian Process Regression to find optimal hyperparameters. I decided to use this method as the computation of the score for one catfamily model may be expensive. In this case bayesian optimization could be a plus. As this optimization methods takes some time as well you should try random search as well as this may be faster.

# %%
import GPyOpt

class Hypertuner:
    
    def __init__(self, model, max_iter=10, max_time=10,max_depth=6, max_l2_leaf_reg=20):
        self.bounds = [{'name': 'depth','type': 'discrete','domain': (1,max_depth)},
                       {'name': 'l2_leaf_reg','type': 'discrete','domain': (1,max_l2_leaf_reg)}]
        self.model = model
        self.max_iter=max_iter
        self.max_time=max_time
        self.best_depth = None
        self.best_l2_leaf_reg = None
    
    def objective(self, params):
        params = params[0]
        params = CatHyperparameter(
            max_depth=params[0],
            l2_leaf_reg=params[1]
        )
        self.model.params = params
        self.model.learn()
        return self.model.score()
    
    def learn(self):
        np.random.seed(777)
        optimizer = GPyOpt.methods.BayesianOptimization(
            f=self.objective, domain=self.bounds,
            acquisition_type ='EI',
            acquisition_par = 0.2,
            exact_eval=True)
        optimizer.run_optimization(self.max_iter, self.max_time)
        optimizer.plot_convergence()
        best = optimizer.X[np.argmin(optimizer.Y)]
        self.best_depth = best[0]
        self.best_l2_leaf_reg = best[1]
        print("Optimal depth is {} and optimal l2-leaf-reg is {}".format(self.best_depth, self.best_l2_leaf_reg))
        print('Optimal RMSE:', np.min(optimizer.Y))
    
    def retrain_catmodel(self):
        params = CatHyperparameter(
            max_depth=self.best_depth,
            l2_leaf_reg=self.best_l2_leaf_reg
        )
        self.model.params = params
        self.model.learn(plot=True)
        return self.model
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[28], line 1
# ----> 1 import GPyOpt
#       3 class Hypertuner:
#       5     def __init__(self, model, max_iter=10, max_time=10,max_depth=6, max_l2_leaf_reg=20):
#
# ModuleNotFoundError: No module named 'GPyOpt'

# %%
pip install GPyOpt
# Out:
# Collecting GPyOpt
#   Using cached GPyOpt-1.2.6-py3-none-any.whl
# Requirement already satisfied: numpy>=1.7 in /Users/aidanszwec/miniconda3/lib/python3.10/site-packages (from GPyOpt) (1.23.5)
# Requirement already satisfied: scipy>=0.16 in /Users/aidanszwec/miniconda3/lib/python3.10/site-packages (from GPyOpt) (1.10.0)
# Collecting GPy>=1.8 (from GPyOpt)
#   Using cached GPy-1.13.1.tar.gz (1.1 MB)
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: six in /Users/aidanszwec/miniconda3/lib/python3.10/site-packages (from GPy>=1.8->GPyOpt) (1.16.0)
# Requirement already satisfied: paramz>=0.9.6 in /Users/aidanszwec/miniconda3/lib/python3.10/site-packages (from GPy>=1.8->GPyOpt) (0.9.6)
# Requirement already satisfied: cython>=0.29 in /Users/aidanszwec/miniconda3/lib/python3.10/site-packages (from GPy>=1.8->GPyOpt) (3.0.8)
# Requirement already satisfied: decorator>=4.0.10 in /Users/aidanszwec/miniconda3/lib/python3.10/site-packages (from paramz>=0.9.6->GPy>=1.8->GPyOpt) (5.1.1)
# Building wheels for collected packages: GPy
#   Building wheel for GPy (setup.py) ... error
#   error: subprocess-exited-with-error
#
#   × python setup.py bdist_wheel did not run successfully.
#   │ exit code: 1
#   ╰─> [398 lines of output]
#       /Users/aidanszwec/miniconda3/lib/python3.10/site-packages/setuptools/dist.py:472: SetuptoolsDeprecationWarning: Invalid dash-separated options
#       !!
#
#               ********************************************************************************
#               Usage of dash-separated 'upload-dir' will not be supported in future
#               versions. Please use the underscore name 'upload_dir' instead.
#
#               By 2024-Sep-26, you need to update your project and remove deprecated calls
#               or your builds will no longer be supported.
#
#               See https://setuptools.pypa.io/en/latest/userguide/declarative_config.html for details.
#               ********************************************************************************
#
#       !!
#         opt = self.warn_dash_deprecation(opt, section)
#       /Users/aidanszwec/miniconda3/lib/python3.10/site-packages/setuptools/__init__.py:80: _DeprecatedInstaller: setuptools.installer and fetch_build_eggs are deprecated.
#       !!
#
#               ********************************************************************************
#               Requirements should be satisfied by a PEP 517 installer.
#               If you are using pip, you can try `pip install --use-pep517`.
#               ********************************************************************************
#
#       !!
#         dist.fetch_build_eggs(dist.setup_requires)
#       /Users/aidanszwec/miniconda3/lib/python3.10/site-packages/setuptools/dist.py:472: SetuptoolsDeprecationWarning: Invalid dash-separated options
#       !!
#
#               ********************************************************************************
#               Usage of dash-separated 'upload-dir' will not be supported in future
#               versions. Please use the underscore name 'upload_dir' instead.
#
#               By 2024-Sep-26, you need to update your project and remove deprecated calls
#               or your builds will no longer be supported.
#
#               See https://setuptools.pypa.io/en/latest/userguide/declarative_config.html for details.
#               ********************************************************************************
#
#       !!
#         opt = self.warn_dash_deprecation(opt, section)
#       running bdist_wheel
#       running build
#       running build_py
#       creating build
#       creating build/lib.macosx-11.1-arm64-cpython-310
#       creating build/lib.macosx-11.1-arm64-cpython-310/GPy
#       copying GPy/__init__.py -> build/lib.macosx-11.1-arm64-cpython-310/GPy
#       copying GPy/__version__.py -> build/lib.macosx-11.1-arm64-cpython-310/GPy
#       creating build/lib.macosx-11.1-arm64-cpython-310/GPy/core
#       copying GPy/core/sparse_gp_mpi.py -> build/lib.macosx-11.1-arm64-cpython-310/GPy/core
#       copying GPy/core/gp_grid.py -> build/lib.macosx-11.1-arm64-cpython-310/GPy/core
#       copying GPy/core/gp.py -> build/lib.macosx-11.1-arm64-cpython-310/GPy/core
#       copying GPy/core/svgp.py -> build/lib.macosx-11.1-arm64-cpython-310/GPy/core
#       copying GPy/core/__init__.py -> build/lib.macosx-11.1-arm64-cpython-310/GPy/core
#       copying GPy/core/sparse_gp.py -> build/lib.macosx-11.1-arm64-cpython-310/GPy/core
#       copying GPy/core/symbolic.py -> build/lib.macosx-11.1-arm64-cpython-310/GPy/core
#       copying GPy/core/model.py -> build/lib.macosx-11.1-arm64-cpython-310/GPy/core
#       copying GPy/core/mapping.py -> build/lib.macosx-11.1-arm64-cpython-310/GPy/core
#       creating build/lib.macosx-11.1-arm64-cpython-310/GPy/core/parameterization
#       copying GPy/core/parameterization/transformations.py -> build/lib.macosx-11.1-arm64-cpython-310/GPy/core/parameterization
#       copying GPy/core/parameterization/__init__.py -> build/lib.macosx-11.1-arm64-cpython-310/GPy/core/parameterization
#       copying GPy/core/parameterization/param.py -> build/lib.macosx-11.1-arm64-cpython-310/GPy/core/parameterization
#       copying GPy/core/parameterization/priorizable.py -> build/lib.macosx-11.1-arm64-cpython-310/GPy/core/parameterization
#       copying GPy/core/parameterization/variational.py -> build/lib.macosx-11.1-arm64-cpython-310/GPy/core/parameterization
#       copying GPy/core/parameterization/priors.py -> build/lib.macosx-11.1-arm64-cpython-310/GPy/core/parameterization
#       copying GPy/core/parameterization/parameterized.py -> build/lib.macosx-11.1-arm64-cpython-310/GPy/core/parameterization
#       creating build/lib.macosx-11.1-arm64-cpython-310/GPy/kern
#       copying GPy/kern/__init__.py -> build/lib.macosx-11.1-arm64-cpython-310/GPy/kern
#       creating build/lib.macosx-11.1-arm64-cpython-310/GPy/kern/src
#       copying GPy/kern/src/ODE_UYC.py -> build/lib.macosx-11.1-arm64-cpython-310/GPy/kern/src
#       copying GPy/kern/src/multioutput_kern.py -> build/lib.macosx-11.1-arm64-cpython-310/GPy/kern/src
#       copying GPy/kern/src/sde_standard_periodic.py -> build/lib.macosx-11.1-arm64-cpython-310/GPy/kern/src
#       copying GPy/kern/src/spline.py -> build/lib.macosx-11.1-arm64-cpython-310/GPy/kern/src
#       copying GPy/kern/src/stationary.py -> build/lib.macosx-11.1-arm64-cpython-310/GPy/kern/src
#       copying GPy/kern/src/sde_brownian.py -> build/lib.macosx-11.1-arm64-cpython-310/GPy/kern/src
#       copying GPy/kern/src/sde_stationary.py -> build/lib.macosx-11.1-arm64-cpython-310/GPy/kern/src
#       copying GPy/kern/src/add.py -> build/lib.macosx-11.1-arm64-cpython-310/GPy/kern/src
#       copying GPy/kern/src/independent_outputs.py -> build/lib.macosx-11.1-arm64-cpython-310/GPy/kern/src
#       copying GPy/kern/src/periodic.py -> build/lib.macosx-11.1-arm64-cpython-310/GPy/kern/src
#       copying GPy/kern/src/integral_limits.py -> build/lib.macosx-11.1-arm64-cpython-310/GPy/kern/src
#       copying GPy/kern/src/eq_ode2.py -> build/lib.macosx-11.1-arm64-cpython-310/GPy/kern/src
#       copying GPy/kern/src/symmetric.py -> build/lib.macosx-11.1-arm64-cpython-310/GPy/kern/src
#       copying GPy/kern/src/linear.py -> build/lib.macosx-11.1-arm64-cpython-310/GPy/kern/src
#       copying GPy/kern/src/integral.py -> build/lib.macosx-11.1-arm64-cpython-310/GPy/kern/src
#       copying GPy/kern/src/sde_matern.py -> build/lib.macosx-11.1-arm64-cpython-310/GPy/kern/src
#       copying GPy/kern/src/coregionalize.py -> build/lib.macosx-11.1-arm64-cpython-310/GPy/kern/src
#       copying GPy/kern/src/sde_linear.py -> build/lib.macosx-11.1-arm64-cpython-310/GPy/kern/src
#       copying GPy/kern/src/__init__.py -> build/lib.macosx-11.1-arm64-cpython-310/GPy/kern/src
#       copying GPy/kern/src/standard_periodic.py -> build/lib.macosx-11.1-arm64-cpython-310/GPy/kern/src
#       copying GPy/kern/src/ODE_UY.py -> build/lib.macosx-11.1-arm64-cpython-310/GPy/kern/src
#       copying GPy/kern/src/kernel_slice_operations.py -> build/lib.macosx-11.1-arm64-cpython-310/GPy/kern/src
#       copying GPy/kern/src/poly.py -> build/lib.macosx-11.1-arm64-cpython-310/GPy/kern/src
#       copying GPy/kern/src/symbolic.py -> build/lib.macosx-11.1-arm64-cpython-310/GPy/kern/src
#       copying GPy/kern/src/mlp.py -> build/lib.macosx-11.1-arm64-cpython-310/GPy/kern/src
#       copying GPy/kern/src/splitKern.py -> build/lib.macosx-11.1-arm64-cpython-310/GPy/kern/src
#       copying GPy/kern/src/rbf.py -> build/lib.macosx-11.1-arm64-cpython-310/GPy/kern/src
#       copying GPy/kern/src/basis_funcs.py -> build/lib.macosx-11.1-arm64-cpython-310/GPy/kern/src
#       copying GPy/kern/src/sde_static.py -> build/lib.macosx-11.1-arm64-cpython-310/GPy/kern/src
#       copying GPy/kern/src/grid_kerns.py -> build/lib.macosx-11.1-arm64-cpython-310/GPy/kern/src
#       copying GPy/kern/src/kern.py -> build/lib.macosx-11.1-arm64-cpython-310/GPy/kern/src
#       copying GPy/kern/src/eq_ode1.py -> build/lib.macosx-11.1-arm64-cpython-310/GPy/kern/src
#       copying GPy/kern/src/ODE_t.py -> build/lib.macosx-11.1-arm64-cpython-310/GPy/kern/src
#       copying GPy/kern/src/brownian.py -> build/lib.macosx-11.1-arm64-cpython-310/GPy/kern/src
#       copying GPy/kern/src/static.py -> build/lib.macosx-11.1-arm64-cpython-310/GPy/kern/src
#       copying GPy/kern/src/diff_kern.py -> build/lib.macosx-11.1-arm64-cpython-310/GPy/kern/src
#       copying GPy/kern/src/multioutput_derivative_kern.py -> build/lib.macosx-11.1-arm64-cpython-310/GPy/kern/src
#       copying GPy/kern/src/prod.py -> build/lib.macosx-11.1-arm64-cpython-310/GPy/kern/src
#       copying GPy/kern/src/trunclinear.py -> build/lib.macosx-11.1-arm64-cpython-310/GPy/kern/src
#       copying GPy/kern/src/multidimensional_integral_limits.py -> build/lib.macosx-11.1-arm64-cpython-310/GPy/kern/src
#       copying GPy/kern/src/ODE_st.py -> build/lib.macosx-11.1-arm64-cpython-310/GPy/kern/src
#       creating build/lib.macosx-11.1-arm64-cpython-310/GPy/kern/src/psi_comp
#       copying GPy/kern/src/psi_comp/sslinear_psi_comp.py -> build/lib.macosx-11.1-arm64-cpython-310/GPy/kern/src/psi_comp
#       copying GPy/kern/src/psi_comp/linear_psi_comp.py -> build/lib.macosx-11.1-arm64-cpython-310/GPy/kern/src/psi_comp
#       copying GPy/kern/src/psi_comp/ssrbf_psi_comp.py -> build/lib.macosx-11.1-arm64-cpython-310/GPy/kern/src/psi_comp
#       copying GPy/kern/src/psi_comp/gaussherm.py -> build/lib.macosx-11.1-arm64-cpython-310/GPy/kern/src/psi_comp
#       copying GPy/kern/src/psi_comp/rbf_psi_gpucomp.py -> build/lib.macosx-11.1-arm64-cpython-310/GPy/kern/src/psi_comp
#       copying GPy/kern/src/psi_comp/__init__.py -> build/lib.macosx-11.1-arm64-cpython-310/GPy/kern/src/psi_comp
#       copying GPy/kern/src/psi_comp/ssrbf_psi_gpucomp.py -> build/lib.macosx-11.1-arm64-cpython-310/GPy/kern/src/psi_comp
#       copying GPy/kern/src/psi_comp/rbf_psi_comp.py -> build/lib.macosx-11.1-arm64-cpython-310/GPy/kern/src/psi_comp
#       creating build/lib.macosx-11.1-arm64-cpython-310/GPy/models
#       copying GPy/models/gp_multiout_regression.py -> build/lib.macosx-11.1-arm64-cpython-310/GPy/models
#       copying GPy/models/warped_gp.py -> build/lib.macosx-11.1-arm64-cpython-310/GPy/models
#       copying GPy/models/dpgplvm.py -> build/lib.macosx-11.1-arm64-cpython-310/GPy/models
#       copying GPy/models/one_vs_all_classification.py -> build/lib.macosx-11.1-arm64-cpython-310/GPy/models
#       copying GPy/models/ss_mrd.py -> build/lib.macosx-11.1-arm64-cpython-310/GPy/models
#       copying GPy/models/gp_offset_regression.py -> build/lib.macosx-11.1-arm64-cpython-310/GPy/models
#       copying GPy/models/gp_heteroscedastic_regression.py -> build/lib.macosx-11.1-arm64-cpython-310/GPy/models
#       copying GPy/models/gp_grid_regression.py -> build/lib.macosx-11.1-arm64-cpython-310/GPy/models
#       copying GPy/models/mrd.py -> build/lib.macosx-11.1-arm64-cpython-310/GPy/models
#       copying GPy/models/bayesian_gplvm_minibatch.py -> build/lib.macosx-11.1-arm64-cpython-310/GPy/models
#       copying GPy/models/gp_kronecker_gaussian_regression.py -> build/lib.macosx-11.1-arm64-cpython-310/GPy/models
#       copying GPy/models/gp_var_gauss.py -> build/lib.macosx-11.1-arm64-cpython-310/GPy/models
#       copying GPy/models/ss_gplvm.py -> build/lib.macosx-11.1-arm64-cpython-310/GPy/models
#       copying GPy/models/sparse_gp_regression_md.py -> build/lib.macosx-11.1-arm64-cpython-310/GPy/models
#       copying GPy/models/sparse_gp_classification.py -> build/lib.macosx-11.1-arm64-cpython-310/GPy/models
#       copying GPy/models/multioutput_gp.py -> build/lib.macosx-11.1-arm64-cpython-310/GPy/models
#       copying GPy/models/state_space_model.py -> build/lib.macosx-11.1-arm64-cpython-310/GPy/models
#       copying GPy/models/gplvm.py -> build/lib.macosx-11.1-arm64-cpython-310/GPy/models
#       copying GPy/models/__init__.py -> build/lib.macosx-11.1-arm64-cpython-310/GPy/models
#       copying GPy/models/gradient_checker.py -> build/lib.macosx-11.1-arm64-cpython-310/GPy/models
#       copying GPy/models/gp_classification.py -> build/lib.macosx-11.1-arm64-cpython-310/GPy/models
#       copying GPy/models/sparse_gp_regression.py -> build/lib.macosx-11.1-arm64-cpython-310/GPy/models
#       copying GPy/models/state_space_setup.py -> build/lib.macosx-11.1-arm64-cpython-310/GPy/models
#       copying GPy/models/state_space_main.py -> build/lib.macosx-11.1-arm64-cpython-310/GPy/models
#       copying GPy/models/gp_regression.py -> build/lib.macosx-11.1-arm64-cpython-310/GPy/models
#       copying GPy/models/gp_multiout_regression_md.py -> build/lib.macosx-11.1-arm64-cpython-310/GPy/models
#       copying GPy/models/tp_regression.py -> build/lib.macosx-11.1-arm64-cpython-310/GPy/models
#       copying GPy/models/sparse_gp_coregionalized_regression.py -> build/lib.macosx-11.1-arm64-cpython-310/GPy/models
#       copying GPy/models/sparse_gp_minibatch.py -> build/lib.macosx-11.1-arm64-cpython-310/GPy/models
#       copying GPy/models/state_space.py -> build/lib.macosx-11.1-arm64-cpython-310/GPy/models
#       copying GPy/models/one_vs_all_sparse_classification.py -> build/lib.macosx-11.1-arm64-cpython-310/GPy/models
#       copying GPy/models/input_warped_gp.py -> build/lib.macosx-11.1-arm64-cpython-310/GPy/models
#       copying GPy/models/ibp_lfm.py -> build/lib.macosx-11.1-arm64-cpython-310/GPy/models
#       copying GPy/models/bcgplvm.py -> build/lib.macosx-11.1-arm64-cpython-310/GPy/models
#       copying GPy/models/bayesian_gplvm.py -> build/lib.macosx-11.1-arm64-cpython-310/GPy/models
#       copying GPy/models/sparse_gplvm.py -> build/lib.macosx-11.1-arm64-cpython-310/GPy/models
#       copying GPy/models/gp_coregionalized_regression.py -> build/lib.macosx-11.1-arm64-cpython-310/GPy/models
#       creating build/lib.macosx-11.1-arm64-cpython-310/GPy/inference
#       copying GPy/inference/__init__.py -> build/lib.macosx-11.1-arm64-cpython-310/GPy/inference
#       creating build/lib.macosx-11.1-arm64-cpython-310/GPy/inference/optimization
#       copying GPy/inference/optimization/__init__.py -> build/lib.macosx-11.1-arm64-cpython-310/GPy/inference/optimization
#       copying GPy/inference/optimization/stochastics.py -> build/lib.macosx-11.1-arm64-cpython-310/GPy/inference/optimization
#       creating build/lib.macosx-11.1-arm64-cpython-310/GPy/inference/mcmc
#       copying GPy/inference/mcmc/__init__.py -> build/lib.macosx-11.1-arm64-cpython-310/GPy/inference/mcmc
#       copying GPy/inference/mcmc/hmc.py -> build/lib.macosx-11.1-arm64-cpython-310/GPy/inference/mcmc
#       copying GPy/inference/mcmc/samplers.py -> build/lib.macosx-11.1-arm64-cpython-310/GPy/inference/mcmc
#       creating build/lib.macosx-11.1-arm64-cpython-310/GPy/inference/latent_function_inference
#       copying GPy/inference/latent_function_inference/inferenceX.py -> build/lib.macosx-11.1-arm64-cpython-310/GPy/inference/latent_function_inference
#       copying GPy/inference/latent_function_inference/laplace.py -> build/lib.macosx-11.1-arm64-cpython-310/GPy/inference/latent_function_inference
#       copying GPy/inference/latent_function_inference/vardtc_svi_multiout.py -> build/lib.macosx-11.1-arm64-cpython-310/GPy/inference/latent_function_inference
#       copying GPy/inference/latent_function_inference/var_dtc_parallel.py -> build/lib.macosx-11.1-arm64-cpython-310/GPy/inference/latent_function_inference
#       copying GPy/inference/latent_function_inference/pep.py -> build/lib.macosx-11.1-arm64-cpython-310/GPy/inference/latent_function_inference
#       copying GPy/inference/latent_function_inference/vardtc_md.py -> build/lib.macosx-11.1-arm64-cpython-310/GPy/inference/latent_function_inference
#       copying GPy/inference/latent_function_inference/dtc.py -> build/lib.macosx-11.1-arm64-cpython-310/GPy/inference/latent_function_inference
#       copying GPy/inference/latent_function_inference/svgp.py -> build/lib.macosx-11.1-arm64-cpython-310/GPy/inference/latent_function_inference
#       copying GPy/inference/latent_function_inference/__init__.py -> build/lib.macosx-11.1-arm64-cpython-310/GPy/inference/latent_function_inference
#       copying GPy/inference/latent_function_inference/var_dtc.py -> build/lib.macosx-11.1-arm64-cpython-310/GPy/inference/latent_function_inference
#       copying GPy/inference/latent_function_inference/gaussian_grid_inference.py -> build/lib.macosx-11.1-arm64-cpython-310/GPy/inference/latent_function_inference
#       copying GPy/inference/latent_function_inference/grid_posterior.py -> build/lib.macosx-11.1-arm64-cpython-310/GPy/inference/latent_function_inference
#       copying GPy/inference/latent_function_inference/exact_gaussian_inference.py -> build/lib.macosx-11.1-arm64-cpython-310/GPy/inference/latent_function_inference
#       copying GPy/inference/latent_function_inference/fitc.py -> build/lib.macosx-11.1-arm64-cpython-310/GPy/inference/latent_function_inference
#       copying GPy/inference/latent_function_inference/expectation_propagation.py -> build/lib.macosx-11.1-arm64-cpython-310/GPy/inference/latent_function_inference
#       copying GPy/inference/latent_function_inference/posterior.py -> build/lib.macosx-11.1-arm64-cpython-310/GPy/inference/latent_function_inference
#       copying GPy/inference/latent_function_inference/vardtc_svi_multiout_miss.py -> build/lib.macosx-11.1-arm64-cpython-310/GPy/inference/latent_function_inference
#       copying GPy/inference/latent_function_inference/exact_studentt_inference.py -> build/lib.macosx-11.1-arm64-cpython-310/GPy/inference/latent_function_inference
#       copying GPy/inference/latent_function_inference/var_gauss.py -> build/lib.macosx-11.1-arm64-cpython-310/GPy/inference/latent_function_inference
#       creating build/lib.macosx-11.1-arm64-cpython-310/GPy/likelihoods
#       copying GPy/likelihoods/student_t.py -> build/lib.macosx-11.1-arm64-cpython-310/GPy/likelihoods
#       copying GPy/likelihoods/weibull.py -> build/lib.macosx-11.1-arm64-cpython-310/GPy/likelihoods
#       copying GPy/likelihoods/poisson.py -> build/lib.macosx-11.1-arm64-cpython-310/GPy/likelihoods
#       copying GPy/likelihoods/__init__.py -> build/lib.macosx-11.1-arm64-cpython-310/GPy/likelihoods
#       copying GPy/likelihoods/exponential.py -> build/lib.macosx-11.1-arm64-cpython-310/GPy/likelihoods
#       copying GPy/likelihoods/loggaussian.py -> build/lib.macosx-11.1-arm64-cpython-310/GPy/likelihoods
#       copying GPy/likelihoods/link_functions.py -> build/lib.macosx-11.1-arm64-cpython-310/GPy/likelihoods
#       copying GPy/likelihoods/mixed_noise.py -> build/lib.macosx-11.1-arm64-cpython-310/GPy/likelihoods
#       copying GPy/likelihoods/multioutput_likelihood.py -> build/lib.macosx-11.1-arm64-cpython-310/GPy/likelihoods
#       copying GPy/likelihoods/bernoulli.py -> build/lib.macosx-11.1-arm64-cpython-310/GPy/likelihoods
#       copying GPy/likelihoods/likelihood.py -> build/lib.macosx-11.1-arm64-cpython-310/GPy/likelihoods
#       copying GPy/likelihoods/loglogistic.py -> build/lib.macosx-11.1-arm64-cpython-310/GPy/likelihoods
#       copying GPy/likelihoods/gaussian.py -> build/lib.macosx-11.1-arm64-cpython-310/GPy/likelihoods
#       copying GPy/likelihoods/gamma.py -> build/lib.macosx-11.1-arm64-cpython-310/GPy/likelihoods
#       copying GPy/likelihoods/binomial.py -> build/lib.macosx-11.1-arm64-cpython-310/GPy/likelihoods
#       creating build/lib.macosx-11.1-arm64-cpython-310/GPy/mappings
#       copying GPy/mappings/kernel.py -> build/lib.macosx-11.1-arm64-cpython-310/GPy/mappings
#       copying GPy/mappings/linear.py -> build/lib.macosx-11.1-arm64-cpython-310/GPy/mappings
#       copying GPy/mappings/piecewise_linear.py -> build/lib.macosx-11.1-arm64-cpython-310/GPy/mappings
#       copying GPy/mappings/__init__.py -> build/lib.macosx-11.1-arm64-cpython-310/GPy/mappings
#       copying GPy/mappings/mlp.py -> build/lib.macosx-11.1-arm64-cpython-310/GPy/mappings
#       copying GPy/mappings/compound.py -> build/lib.macosx-11.1-arm64-cpython-310/GPy/mappings
#       copying GPy/mappings/constant.py -> build/lib.macosx-11.1-arm64-cpython-310/GPy/mappings
#       copying GPy/mappings/mlpext.py -> build/lib.macosx-11.1-arm64-cpython-310/GPy/mappings
#       copying GPy/mappings/identity.py -> build/lib.macosx-11.1-arm64-cpython-310/GPy/mappings
#       copying GPy/mappings/additive.py -> build/lib.macosx-11.1-arm64-cpython-310/GPy/mappings
#       creating build/lib.macosx-11.1-arm64-cpython-310/GPy/examples
#       copying GPy/examples/regression.py -> build/lib.macosx-11.1-arm64-cpython-310/GPy/examples
#       copying GPy/examples/classification.py -> build/lib.macosx-11.1-arm64-cpython-310/GPy/examples
#       copying GPy/examples/__init__.py -> build/lib.macosx-11.1-arm64-cpython-310/GPy/examples
#       copying GPy/examples/non_gaussian.py -> build/lib.macosx-11.1-arm64-cpython-310/GPy/examples
#       copying GPy/examples/dimensionality_reduction.py -> build/lib.macosx-11.1-arm64-cpython-310/GPy/examples
#       copying GPy/examples/state_space.py -> build/lib.macosx-11.1-arm64-cpython-310/GPy/examples
#       creating build/lib.macosx-11.1-arm64-cpython-310/GPy/testing
#       copying GPy/testing/state_space_main_tests.py -> build/lib.macosx-11.1-arm64-cpython-310/GPy/testing
#       copying GPy/testing/test_likelihood.py -> build/lib.macosx-11.1-arm64-cpython-310/GPy/testing
#       copying GPy/testing/test_model.py -> build/lib.macosx-11.1-arm64-cpython-310/GPy/testing
#       copying GPy/testing/test_inference.py -> build/lib.macosx-11.1-arm64-cpython-310/GPy/testing
#       copying GPy/testing/test_linalg.py -> build/lib.macosx-11.1-arm64-cpython-310/GPy/testing
#       copying GPy/testing/test_gpy_kernels_state_space.py -> build/lib.macosx-11.1-arm64-cpython-310/GPy/testing
#       copying GPy/testing/test_plotting.py -> build/lib.macosx-11.1-arm64-cpython-310/GPy/testing
#       copying GPy/testing/test_grid.py -> build/lib.macosx-11.1-arm64-cpython-310/GPy/testing
#       copying GPy/testing/test_misc.py -> build/lib.macosx-11.1-arm64-cpython-310/GPy/testing
#       copying GPy/testing/test_pickle.py -> build/lib.macosx-11.1-arm64-cpython-310/GPy/testing
#       copying GPy/testing/test_tp.py -> build/lib.macosx-11.1-arm64-cpython-310/GPy/testing
#       copying GPy/testing/test_gp.py -> build/lib.macosx-11.1-arm64-cpython-310/GPy/testing
#       copying GPy/testing/__init__.py -> build/lib.macosx-11.1-arm64-cpython-310/GPy/testing
#       copying GPy/testing/test_rv_transformation.py -> build/lib.macosx-11.1-arm64-cpython-310/GPy/testing
#       copying GPy/testing/test_svgp.py -> build/lib.macosx-11.1-arm64-cpython-310/GPy/testing
#       copying GPy/testing/test_util.py -> build/lib.macosx-11.1-arm64-cpython-310/GPy/testing
#       copying GPy/testing/test_link_function.py -> build/lib.macosx-11.1-arm64-cpython-310/GPy/testing
#       copying GPy/testing/test_pep.py -> build/lib.macosx-11.1-arm64-cpython-310/GPy/testing
#       copying GPy/testing/mpi_test__.py -> build/lib.macosx-11.1-arm64-cpython-310/GPy/testing
#       copying GPy/testing/test_cython.py -> build/lib.macosx-11.1-arm64-cpython-310/GPy/testing
#       copying GPy/testing/test_quadrature.py -> build/lib.macosx-11.1-arm64-cpython-310/GPy/testing
#       copying GPy/testing/test_kernel.py -> build/lib.macosx-11.1-arm64-cpython-310/GPy/testing
#       copying GPy/testing/fitc.py -> build/lib.macosx-11.1-arm64-cpython-310/GPy/testing
#       copying GPy/testing/test_minibatch.py -> build/lib.macosx-11.1-arm64-cpython-310/GPy/testing
#       copying GPy/testing/test_meanfunc.py -> build/lib.macosx-11.1-arm64-cpython-310/GPy/testing
#       copying GPy/testing/test_ep_likelihood.py -> build/lib.macosx-11.1-arm64-cpython-310/GPy/testing
#       copying GPy/testing/test_serialization.py -> build/lib.macosx-11.1-arm64-cpython-310/GPy/testing
#       copying GPy/testing/test_prior.py -> build/lib.macosx-11.1-arm64-cpython-310/GPy/testing
#       copying GPy/testing/test_variational.py -> build/lib.macosx-11.1-arm64-cpython-310/GPy/testing
#       copying GPy/testing/test_mapping.py -> build/lib.macosx-11.1-arm64-cpython-310/GPy/testing
#       creating build/lib.macosx-11.1-arm64-cpython-310/GPy/util
#       copying GPy/util/functions.py -> build/lib.macosx-11.1-arm64-cpython-310/GPy/util
#       copying GPy/util/misc.py -> build/lib.macosx-11.1-arm64-cpython-310/GPy/util
#       copying GPy/util/config.py -> build/lib.macosx-11.1-arm64-cpython-310/GPy/util
#       copying GPy/util/input_warping_functions.py -> build/lib.macosx-11.1-arm64-cpython-310/GPy/util
#       copying GPy/util/classification.py -> build/lib.macosx-11.1-arm64-cpython-310/GPy/util
#       copying GPy/util/quad_integrate.py -> build/lib.macosx-11.1-arm64-cpython-310/GPy/util
#       copying GPy/util/gpu_init.py -> build/lib.macosx-11.1-arm64-cpython-310/GPy/util
#       copying GPy/util/datasets.py -> build/lib.macosx-11.1-arm64-cpython-310/GPy/util
#       copying GPy/util/multioutput.py -> build/lib.macosx-11.1-arm64-cpython-310/GPy/util
#       copying GPy/util/__init__.py -> build/lib.macosx-11.1-arm64-cpython-310/GPy/util
#       copying GPy/util/cluster_with_offset.py -> build/lib.macosx-11.1-arm64-cpython-310/GPy/util
#       copying GPy/util/block_matrices.py -> build/lib.macosx-11.1-arm64-cpython-310/GPy/util
#       copying GPy/util/initialization.py -> build/lib.macosx-11.1-arm64-cpython-310/GPy/util
#       copying GPy/util/netpbmfile.py -> build/lib.macosx-11.1-arm64-cpython-310/GPy/util
#       copying GPy/util/subarray_and_sorting.py -> build/lib.macosx-11.1-arm64-cpython-310/GPy/util
#       copying GPy/util/linalg.py -> build/lib.macosx-11.1-arm64-cpython-310/GPy/util
#       copying GPy/util/diag.py -> build/lib.macosx-11.1-arm64-cpython-310/GPy/util
#       copying GPy/util/debug.py -> build/lib.macosx-11.1-arm64-cpython-310/GPy/util
#       copying GPy/util/choleskies.py -> build/lib.macosx-11.1-arm64-cpython-310/GPy/util
#       copying GPy/util/warping_functions.py -> build/lib.macosx-11.1-arm64-cpython-310/GPy/util
#       copying GPy/util/pca.py -> build/lib.macosx-11.1-arm64-cpython-310/GPy/util
#       copying GPy/util/ln_diff_erfs.py -> build/lib.macosx-11.1-arm64-cpython-310/GPy/util
#       copying GPy/util/univariate_Gaussian.py -> build/lib.macosx-11.1-arm64-cpython-310/GPy/util
#       copying GPy/util/mocap.py -> build/lib.macosx-11.1-arm64-cpython-310/GPy/util
#       copying GPy/util/normalizer.py -> build/lib.macosx-11.1-arm64-cpython-310/GPy/util
#       copying GPy/util/parallel.py -> build/lib.macosx-11.1-arm64-cpython-310/GPy/util
#       copying GPy/util/linalg_gpu.py -> build/lib.macosx-11.1-arm64-cpython-310/GPy/util
#       copying GPy/util/squashers.py -> build/lib.macosx-11.1-arm64-cpython-310/GPy/util
#       copying GPy/util/decorators.py -> build/lib.macosx-11.1-arm64-cpython-310/GPy/util
#       creating build/lib.macosx-11.1-arm64-cpython-310/GPy/plotting
#       copying GPy/plotting/Tango.py -> build/lib.macosx-11.1-arm64-cpython-310/GPy/plotting
#       copying GPy/plotting/__init__.py -> build/lib.macosx-11.1-arm64-cpython-310/GPy/plotting
#       copying GPy/plotting/abstract_plotting_library.py -> build/lib.macosx-11.1-arm64-cpython-310/GPy/plotting
#       creating build/lib.macosx-11.1-arm64-cpython-310/GPy/plotting/gpy_plot
#       copying GPy/plotting/gpy_plot/kernel_plots.py -> build/lib.macosx-11.1-arm64-cpython-310/GPy/plotting/gpy_plot
#       copying GPy/plotting/gpy_plot/latent_plots.py -> build/lib.macosx-11.1-arm64-cpython-310/GPy/plotting/gpy_plot
#       copying GPy/plotting/gpy_plot/gp_plots.py -> build/lib.macosx-11.1-arm64-cpython-310/GPy/plotting/gpy_plot
#       copying GPy/plotting/gpy_plot/__init__.py -> build/lib.macosx-11.1-arm64-cpython-310/GPy/plotting/gpy_plot
#       copying GPy/plotting/gpy_plot/data_plots.py -> build/lib.macosx-11.1-arm64-cpython-310/GPy/plotting/gpy_plot
#       copying GPy/plotting/gpy_plot/plot_util.py -> build/lib.macosx-11.1-arm64-cpython-310/GPy/plotting/gpy_plot
#       copying GPy/plotting/gpy_plot/inference_plots.py -> build/lib.macosx-11.1-arm64-cpython-310/GPy/plotting/gpy_plot
#       creating build/lib.macosx-11.1-arm64-cpython-310/GPy/plotting/matplot_dep
#       copying GPy/plotting/matplot_dep/maps.py -> build/lib.macosx-11.1-arm64-cpython-310/GPy/plotting/matplot_dep
#       copying GPy/plotting/matplot_dep/svig_plots.py -> build/lib.macosx-11.1-arm64-cpython-310/GPy/plotting/matplot_dep
#       copying GPy/plotting/matplot_dep/util.py -> build/lib.macosx-11.1-arm64-cpython-310/GPy/plotting/matplot_dep
#       copying GPy/plotting/matplot_dep/priors_plots.py -> build/lib.macosx-11.1-arm64-cpython-310/GPy/plotting/matplot_dep
#       copying GPy/plotting/matplot_dep/__init__.py -> build/lib.macosx-11.1-arm64-cpython-310/GPy/plotting/matplot_dep
#       copying GPy/plotting/matplot_dep/base_plots.py -> build/lib.macosx-11.1-arm64-cpython-310/GPy/plotting/matplot_dep
#       copying GPy/plotting/matplot_dep/visualize.py -> build/lib.macosx-11.1-arm64-cpython-310/GPy/plotting/matplot_dep
#       copying GPy/plotting/matplot_dep/plot_definitions.py -> build/lib.macosx-11.1-arm64-cpython-310/GPy/plotting/matplot_dep
#       copying GPy/plotting/matplot_dep/mapping_plots.py -> build/lib.macosx-11.1-arm64-cpython-310/GPy/plotting/matplot_dep
#       copying GPy/plotting/matplot_dep/defaults.py -> build/lib.macosx-11.1-arm64-cpython-310/GPy/plotting/matplot_dep
#       copying GPy/plotting/matplot_dep/ssgplvm.py -> build/lib.macosx-11.1-arm64-cpython-310/GPy/plotting/matplot_dep
#       copying GPy/plotting/matplot_dep/img_plots.py -> build/lib.macosx-11.1-arm64-cpython-310/GPy/plotting/matplot_dep
#       copying GPy/plotting/matplot_dep/variational_plots.py -> build/lib.macosx-11.1-arm64-cpython-310/GPy/plotting/matplot_dep
#       creating build/lib.macosx-11.1-arm64-cpython-310/GPy/plotting/matplot_dep/controllers
#       copying GPy/plotting/matplot_dep/controllers/imshow_controller.py -> build/lib.macosx-11.1-arm64-cpython-310/GPy/plotting/matplot_dep/controllers
#       copying GPy/plotting/matplot_dep/controllers/__init__.py -> build/lib.macosx-11.1-arm64-cpython-310/GPy/plotting/matplot_dep/controllers
#       copying GPy/plotting/matplot_dep/controllers/axis_event_controller.py -> build/lib.macosx-11.1-arm64-cpython-310/GPy/plotting/matplot_dep/controllers
#       creating build/lib.macosx-11.1-arm64-cpython-310/GPy/plotting/plotly_dep
#       copying GPy/plotting/plotly_dep/__init__.py -> build/lib.macosx-11.1-arm64-cpython-310/GPy/plotting/plotly_dep
#       copying GPy/plotting/plotly_dep/plot_definitions.py -> build/lib.macosx-11.1-arm64-cpython-310/GPy/plotting/plotly_dep
#       copying GPy/plotting/plotly_dep/defaults.py -> build/lib.macosx-11.1-arm64-cpython-310/GPy/plotting/plotly_dep
#       running egg_info
#       writing GPy.egg-info/PKG-INFO
#       writing dependency_links to GPy.egg-info/dependency_links.txt
#       writing requirements to GPy.egg-info/requires.txt
#       writing top-level names to GPy.egg-info/top_level.txt
#       reading manifest file 'GPy.egg-info/SOURCES.txt'
#       reading manifest template 'MANIFEST.in'
#       adding license file 'LICENSE.txt'
#       adding license file 'AUTHORS.txt'
#       writing manifest file 'GPy.egg-info/SOURCES.txt'
#       /Users/aidanszwec/miniconda3/lib/python3.10/site-packages/setuptools/command/build_py.py:207: _Warning: Package 'GPy.kern.src.todo' is absent from the `packages` configuration.
#       !!
#
#               ********************************************************************************
#               ############################
#               # Package would be ignored #
#               ############################
#               Python recognizes 'GPy.kern.src.todo' as an importable package[^1],
#               but it is absent from setuptools' `packages` configuration.
#
#               This leads to an ambiguous overall configuration. If you want to distribute this
#               package, please make sure that 'GPy.kern.src.todo' is explicitly added
#               to the `packages` configuration field.
#
#               Alternatively, you can also rely on setuptools' discovery methods
#               (for example by using `find_namespace_packages(...)`/`find_namespace:`
#               instead of `find_packages(...)`/`find:`).
#
#               You can read more about "package discovery" on setuptools documentation page:
#
#               - https://setuptools.pypa.io/en/latest/userguide/package_discovery.html
#
#               If you don't want 'GPy.kern.src.todo' to be distributed and are
#               already explicitly excluding 'GPy.kern.src.todo' via
#               `find_namespace_packages(...)/find_namespace` or `find_packages(...)/find`,
#               you can try to use `exclude_package_data`, or `include-package-data=False` in
#               combination with a more fine grained `package-data` configuration.
#
#               You can read more about "package data files" on setuptools documentation page:
#
#               - https://setuptools.pypa.io/en/latest/userguide/datafiles.html
#
#
#               [^1]: For Python, any directory (with suitable naming) can be imported,
#                     even if it does not contain any `.py` files.
#                     On the other hand, currently there is no concept of package data
#                     directory, all directories are treated like packages.
#               ********************************************************************************
#
#       !!
#         check.warn(importable)
#       copying GPy/defaults.cfg -> build/lib.macosx-11.1-arm64-cpython-310/GPy
#       copying GPy/installation.cfg -> build/lib.macosx-11.1-arm64-cpython-310/GPy
#       copying GPy/kern/src/coregionalize_cython.c -> build/lib.macosx-11.1-arm64-cpython-310/GPy/kern/src
#       copying GPy/kern/src/coregionalize_cython.pyx -> build/lib.macosx-11.1-arm64-cpython-310/GPy/kern/src
#       copying GPy/kern/src/stationary_cython.c -> build/lib.macosx-11.1-arm64-cpython-310/GPy/kern/src
#       copying GPy/kern/src/stationary_cython.pyx -> build/lib.macosx-11.1-arm64-cpython-310/GPy/kern/src
#       copying GPy/kern/src/stationary_utils.c -> build/lib.macosx-11.1-arm64-cpython-310/GPy/kern/src
#       copying GPy/kern/src/stationary_utils.h -> build/lib.macosx-11.1-arm64-cpython-310/GPy/kern/src
#       copying GPy/kern/src/sympy_helpers.h -> build/lib.macosx-11.1-arm64-cpython-310/GPy/kern/src
#       creating build/lib.macosx-11.1-arm64-cpython-310/GPy/kern/src/todo
#       copying GPy/kern/src/todo/odekern1.c -> build/lib.macosx-11.1-arm64-cpython-310/GPy/kern/src/todo
#       copying GPy/models/state_space_cython.c -> build/lib.macosx-11.1-arm64-cpython-310/GPy/models
#       copying GPy/models/state_space_cython.pyx -> build/lib.macosx-11.1-arm64-cpython-310/GPy/models
#       copying GPy/util/choleskies_cython.c -> build/lib.macosx-11.1-arm64-cpython-310/GPy/util
#       copying GPy/util/choleskies_cython.pyx -> build/lib.macosx-11.1-arm64-cpython-310/GPy/util
#       copying GPy/util/data_resources.json -> build/lib.macosx-11.1-arm64-cpython-310/GPy/util
#       copying GPy/util/football_teams.json -> build/lib.macosx-11.1-arm64-cpython-310/GPy/util
#       copying GPy/util/linalg_cython.c -> build/lib.macosx-11.1-arm64-cpython-310/GPy/util
#       copying GPy/util/linalg_cython.pyx -> build/lib.macosx-11.1-arm64-cpython-310/GPy/util
#       running build_ext
#       Compiling GPy/kern/src/stationary_cython.pyx because it depends on /Users/aidanszwec/miniconda3/lib/python3.10/site-packages/Cython/Includes/libc/string.pxd.
#       [1/1] Cythonizing GPy/kern/src/stationary_cython.pyx
#       /Users/aidanszwec/miniconda3/lib/python3.10/site-packages/Cython/Compiler/Main.py:381: FutureWarning: Cython directive 'language_level' not set, using '3str' for now (Py3). This has changed from earlier releases! File: /private/var/folders/tt/4vvvkt6n7zx9x7hm71czzc280000gn/T/pip-install-8jrdqly6/gpy_65a4abe0da734036b1cb7239e15366d1/GPy/kern/src/stationary_cython.pyx
#         tree = Parsing.p_module(s, pxd, full_module_name)
#       building 'GPy.kern.src.stationary_cython' extension
#       creating build/temp.macosx-11.1-arm64-cpython-310
#       creating build/temp.macosx-11.1-arm64-cpython-310/GPy
#       creating build/temp.macosx-11.1-arm64-cpython-310/GPy/kern
#       creating build/temp.macosx-11.1-arm64-cpython-310/GPy/kern/src
#       clang -Wno-unused-result -Wsign-compare -Wunreachable-code -DNDEBUG -fwrapv -O2 -Wall -fPIC -O2 -isystem /Users/aidanszwec/miniconda3/include -arch arm64 -fPIC -O2 -isystem /Users/aidanszwec/miniconda3/include -arch arm64 -I/Users/aidanszwec/miniconda3/lib/python3.10/site-packages/numpy/core/include -I. -I/Users/aidanszwec/miniconda3/include/python3.10 -c GPy/kern/src/stationary_cython.c -o build/temp.macosx-11.1-arm64-cpython-310/GPy/kern/src/stationary_cython.o -O3
#       xcrun: error: invalid active developer path (/Library/Developer/CommandLineTools), missing xcrun at: /Library/Developer/CommandLineTools/usr/bin/xcrun
#       error: command '/usr/bin/clang' failed with exit code 1
#       [end of output]
#
#   note: This error originates from a subprocess, and is likely not a problem with pip.
#   ERROR: Failed building wheel for GPy
#   Running setup.py clean for GPy
# Failed to build GPy
# ERROR: Could not build wheels for GPy, which is required to install pyproject.toml-based projects
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install pip==23.3.2
# Out:
# Collecting pip==23.3.2
#   Using cached pip-23.3.2-py3-none-any.whl (2.1 MB)
# Installing collected packages: pip
#   Attempting uninstall: pip
#     Found existing installation: pip 21.3.1
#     Uninstalling pip-21.3.1:
#       Successfully uninstalled pip-21.3.1
# Successfully installed pip-23.3.2
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install pyproject-toml
# Out:
# Collecting pyproject-toml
#   Downloading pyproject_toml-0.0.10-py3-none-any.whl (6.9 kB)
# Requirement already satisfied: setuptools>=42 in /Users/aidanszwec/miniconda3/lib/python3.10/site-packages (from pyproject-toml) (69.0.3)
# Requirement already satisfied: wheel in /Users/aidanszwec/miniconda3/lib/python3.10/site-packages (from pyproject-toml) (0.42.0)
# Requirement already satisfied: toml in /Users/aidanszwec/miniconda3/lib/python3.10/site-packages (from pyproject-toml) (0.10.2)
# Requirement already satisfied: jsonschema in /Users/aidanszwec/miniconda3/lib/python3.10/site-packages (from pyproject-toml) (4.16.0)
# Requirement already satisfied: attrs>=17.4.0 in /Users/aidanszwec/miniconda3/lib/python3.10/site-packages (from jsonschema->pyproject-toml) (22.1.0)
# Requirement already satisfied: pyrsistent!=0.17.0,!=0.17.1,!=0.17.2,>=0.14.0 in /Users/aidanszwec/miniconda3/lib/python3.10/site-packages (from jsonschema->pyproject-toml) (0.18.0)
# Installing collected packages: pyproject-toml
# Successfully installed pyproject-toml-0.0.10
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# **Time series validation Catfamily**
#
# This model holds the information about how to split the data into validation chunks and it organizes the training with sliding window validation. Furthermore it can return a score as the mean over all RMSE scores of its models.

# %%
class CatFamily:
    
    def __init__(self, params, X, y, n_splits=2):
        self.family = {}
        self.cat_features_idx = np.where(X.dtypes != np.float)[0]
        self.X = X.values
        self.y = y.values
        self.n_splits = n_splits
        self.params = params
    
    def set_validation_strategy(self):
        self.cv = TimeSeriesSplit(max_train_size = None,
                                  n_splits = self.n_splits)
        self.gen = self.cv.split(self.X)
    
    def get_split(self):
        train_idx, val_idx = next(self.gen)
        x_train, x_val = self.X[train_idx], self.X[val_idx]
        y_train, y_val = self.y[train_idx], self.y[val_idx]
        train_pool = Pool(x_train, y_train, cat_features=self.cat_features_idx)
        val_pool = Pool(x_val, y_val, cat_features=self.cat_features_idx)
        return train_pool, val_pool
    
    def learn(self):
        self.set_validation_strategy()
        self.model_names = []
        self.model_scores = []
        for split in range(self.n_splits):
            name = 'Model_cv_' + str(split) + '/'
            train_pool, val_pool = self.get_split()
            self.model_names.append(name)
            self.family[name], score = self.fit_catmodel(name, train_pool, val_pool)
            self.model_scores.append(score)
    
    def fit_catmodel(self, name, train_pool, val_pool):
        cat = Catmodel(name, train_pool, val_pool, self.params)
        cat.prepare_model()
        cat.learn()
        score = cat.score()
        return cat, score
    
    def score(self):
        return np.mean(self.model_scores)
    
    def show_learning(self):
        widget = MetricVisualizer(self.model_names)
        widget.start()

    def show_importances(self):
        name = self.model_names[-1]
        cat = self.family[name]
        explainer = shap.TreeExplainer(cat.model)
        shap_values = explainer.shap_values(cat.val_pool)
        return shap.summary_plot(shap_values, X, plot_type="bar")

# %% [markdown]
# ### Baseline model & result analysis  <a class="anchor" id="baseline"></a>
#
# Let's see how good this model performs without feature engineering and hyperparameter search:

# %%
daily_data.head()

# %%
week = daily_data.Week.max() - 2
print("Validation after week {}".format(week))
print("Validation starts at timepoint {}".format(
    daily_data[daily_data.Week==week].Date.min()
))

# %%
X = daily_data.drop(["Quantity", "Revenue", "Date"], axis=1)
daily_data.Quantity = np.log(daily_data.Quantity)
y = daily_data.Quantity
params = CatHyperparameter()

model = Catmodel("baseline", params)
model.set_data(X,y, week)
model.learn(plot=True)

# %% [markdown]
# If you have forked this kernel and are in interactive model you can see that the model loss has converged. How big is the evaluated root mean square error on validation data?

# %%
model.score()

# %% [markdown]
# This value is high, but as already mentioned the RSME is influenced by outliers and we should take a look at the distribution of individual absolute errors:

# %%
model.show_val_results();
# Out:
# Median absolute error: 0.7892396677686456

# %% [markdown]
# * We can see that the **distribution of absolute errors of single predictions is right skewed.**
# * The **median single error (black) is half of the RMSE score and significantly lower**.
# * By plotting the target versus prediction we can see that we **made higher errors for validation entries that have high true quantity values above 30**. The strong blue line shows the identity where predictions are close to target values. **To improve we need to make better predictions for products with true high quantities during validation time**.

# %%
model.show_importances()

# %% [markdown]
# * We can see that the **stock code as well as the description of the products are very important**. They do not have a color as they are not numerical and do not have low or high values.
# * The **weekday** is an important feature as well. We have already seen this by exploring the data. Low values from monday up to thursday are those days where the retailer sales most products. In contrast high values (friday to sunday) only yield a few sales.

# %%
model.show_importances(kind=None)

# %% [markdown]
# * Take a look at the **weekday to understand this plot**: Low values (0 to 3) correspond to Monday, Tuesday, Wednesday and Thursday. These are days with high amount of product sales (high quantity target values). They are colored in blue and **push towards higher sharp values and consequently to higher predicted quantity values**. Higher weekday values suite to friday, saturday and sunday. They are colored in red and **push towards negative sharp values and to lower predicted values**. This confirms to the observations we made during exploration of weekday and the sum of daily quantities.
# * The **StockCode and the Description** are important features but they are also **very complex**. We have seen that we have close to 4000 different stock codes and even more descriptions. To improve we should **try to engineer features that are able to descripe the products in a more general way**.

# %%
np.mean(np.abs(np.exp(model.results.prediction) - np.exp(model.results.Quantity)))
# Out:
# 9.70732224604555

# %%
np.median(np.abs(np.exp(model.results.prediction) - np.exp(model.results.Quantity)))
# Out:
# 4.77030760517831

# %% [markdown]
# ### Bayesian Hyperparameter Search with GPyOpt <a class="anchor" id="hypersearch"></a>
#
# Ok, now we have gained some feeling for a single model. Let's find out if we can obtain a better score after hyperparameter search:

# %%
#search = Hypertuner(model, max_depth=5, max_l2_leaf_reg=30)
#search.learn()
#model = search.retrain_catmodel()
#print(model.score())
#model.show_importances(kind=None)

# %% [markdown]
# ## Feature engineering

# %% [markdown]
# ### Creating product types

# %%
products = pd.DataFrame(index=data.loc[data.Week < week].StockCode.unique(), columns = ["MedianPrice"])

products["MedianPrice"] = data.loc[data.Week < week].groupby("StockCode").UnitPrice.median()
products["MedianQuantities"] = data.loc[data.Week < week].groupby("StockCode").Quantity.median()
products["Customers"] = data.loc[data.Week < week].groupby("StockCode").CustomerID.nunique()
products["DescriptionLength"] = data.loc[data.Week < week].groupby("StockCode").DescriptionLength.median()
#products["StockCode"] = products.index.values
org_cols = np.copy(products.columns.values)
products.head()
# Out:
#        MedianPrice  MedianQuantities  Customers  DescriptionLength
# 71053         3.75               4.0        137               19.0
# 22752         8.50               2.0        163               28.0
# 21730         4.95               3.0         64               33.0
# 22633         2.10               4.0        263               22.0
# 22632         2.10               4.0        227               25.0

# %%
for col in org_cols:
    if col != "StockCode":
        products[col] = boxcox(products[col])[0]

# %%
fig, ax = plt.subplots(1,3,figsize=(20,5))
ax[0].scatter(products.MedianPrice.values, products.MedianQuantities.values,
           c=products.Customers.values, cmap="coolwarm_r")
ax[0].set_xlabel("Boxcox-Median-UnitPrice")
ax[0].set_ylabel("Boxcox-Median-Quantities")
# Out:
# Text(0, 0.5, 'Boxcox-Median-Quantities')

# %%
X = products.values
scaler = StandardScaler()
X = scaler.fit_transform(X)

# %%
km = KMeans(n_clusters=30)
products["cluster"] = km.fit_predict(X)

daily_data["ProductType"] = daily_data.StockCode.map(products.cluster)
daily_data.ProductType = daily_data.ProductType.astype("object")
daily_data.head()
# Out:
#         Date  Year  Quarter  Month  Week  Weekday  Dayofyear  Day StockCode  \
# 0 2010-12-01  2010        4     12    48        2        335    1     10002
# 1 2010-12-01  2010        4     12    48        2        335    1     10125
# 2 2010-12-01  2010        4     12    48        2        335    1     10133
# 3 2010-12-01  2010        4     12    48        2        335    1     16014
# 4 2010-12-01  2010        4     12    48        2        335    1     16016
#
#    Quantity  Revenue ProductType
# 0  4.094345    51.00        20.0
# 1  0.693147     1.70        17.0
# 2  1.609438     4.25         5.0
# 3  2.302585     4.20         2.0
# 4  2.302585     8.50        25.0

# %% [markdown]
# ## Baseline for product types

# %%
daily_data["KnownStockCodeUnitPriceMedian"] = daily_data.StockCode.map(
    data.groupby("StockCode").UnitPrice.median())

known_price_iqr = data.groupby("StockCode").UnitPrice.quantile(0.75) 
known_price_iqr -= data.groupby("StockCode").UnitPrice.quantile(0.25) 
daily_data["KnownStockCodeUnitPriceIQR"] = daily_data.StockCode.map(known_price_iqr)

# %%
to_group = ["StockCode", "Year", "Month", "Week", "Weekday"]

daily_data = daily_data.set_index(to_group)
daily_data["KnownStockCodePrice_WW_median"] = daily_data.index.map(
    data.groupby(to_group).UnitPrice.median())
daily_data["KnownStockCodePrice_WW_mean"] = daily_data.index.map(
    data.groupby(to_group).UnitPrice.mean().apply(lambda l: np.round(l, 2)))
daily_data["KnownStockCodePrice_WW_std"] = daily_data.index.map(
    data.groupby(to_group).UnitPrice.std().apply(lambda l: np.round(l, 2)))

daily_data = daily_data.reset_index()

# %%
daily_data.head()
# Out:
#   StockCode  Year  Month  Week  Weekday       Date  Quarter  Dayofyear  Day  \
# 0     10002  2010     12    48        2 2010-12-01        4        335    1
# 1     10125  2010     12    48        2 2010-12-01        4        335    1
# 2     10133  2010     12    48        2 2010-12-01        4        335    1
# 3     16014  2010     12    48        2 2010-12-01        4        335    1
# 4     16016  2010     12    48        2 2010-12-01        4        335    1
#
#    Quantity  Revenue ProductType  KnownStockCodeUnitPriceMedian  \
# 0  4.094345    51.00        20.0                           0.85
# 1  0.693147     1.70        17.0                           0.85
# 2  1.609438     4.25         5.0                           0.42
# 3  2.302585     4.20         2.0                           0.42
# 4  2.302585     8.50        25.0                           0.85
#
#    KnownStockCodeUnitPriceIQR  KnownStockCodePrice_WW_median  \
# 0                      0.0000                           0.85
# 1                      0.0000                           0.85
# 2                      0.3225                           0.85
# 3                      0.0000                           0.42
# 4                      0.0000                           0.85
#
#    KnownStockCodePrice_WW_mean  KnownStockCodePrice_WW_std
# 0                         0.85                         0.0
# 1                         0.85                         NaN
# 2                         0.85                         NaN
# 3                         0.42                         NaN
# 4                         0.85                         NaN

# %% [markdown]
# ### Temporal patterns

# %%
plt.figure(figsize=(20,5))
plt.plot(daily_data.groupby("Date").Quantity.sum(), marker='+', c="darkorange")
plt.plot(daily_data.groupby("Date").Quantity.sum().rolling(window=30, center=True).mean(),
        c="red")
plt.xticks(rotation=90);
plt.title("How many quantities are sold per day over the given time?");

# %%
fig, ax = plt.subplots(1,2,figsize=(20,5))

weekdays = ["Monday", "Tuesday", "Wednesday", "Thursday", "Friday", "Saturday", "Sunday"]
yearmonth = ["Dec-2010", "Jan-2011", "Feb-2011", "Mar-2011", "Apr-2011", "May-2011",
             "Jun-2011", "Jul-1011", "Aug-2011", "Sep-2011", "Oct-2011", "Nov-2011", 
             "Dec-2011"]

daily_data.groupby("Weekday").Quantity.sum().plot(
    ax=ax[0], marker='o', label="Quantity", c="darkorange");
ax[0].legend();
ax[0].set_xticks(np.arange(0,7))
ax[0].set_xticklabels(weekdays);
ax[0].set_xlabel("")
ax[0].set_title("Total sales per weekday");

ax[1].plot(daily_data.groupby(["Year", "Month"]).Quantity.sum().values,
    marker='o', label="Quantities", c="darkorange");
ax[1].set_xticklabels(yearmonth, rotation=90)
ax[1].set_xticks(np.arange(0, len(yearmonth)))
ax[1].legend();
ax[1].set_title("Total sales per month");

# %% [markdown]
# Both visualisations yield further interesting insights:
#
# * **Thursday** seems to be the day on which most products are sold.
# * In contrast **friday, and sunday** have very **low transactions**
# * On **saturday** there are **no transactions** at all
# * The **pre-Christmas season** starts in **september and shows a peak in november**
# * Indeed **february and april are month with very low sales**.
#
# Let's create some new features for our daily aggregation that may be helpful to make better predictions:

# %%
daily_data["PreChristmas"] = (daily_data.Dayofyear <= 358) & (daily_data.Dayofyear >= 243)

# %%
for col in ["Weekday", "Month", "Quarter"]:
    daily_data = daily_data.set_index(col)
    daily_data[col+"Quantity_mean"] = daily_data.loc[daily_data.Week < week].groupby(col).Quantity.mean()
    daily_data[col+"Quantity_median"] = daily_data.loc[daily_data.Week < week].groupby(col).Quantity.median()
    daily_data[col+"Quantity_mean_median_diff"] = daily_data[col+"Quantity_mean"] - daily_data[col+"Quantity_median"]
    daily_data[col+"Quantity_IQR"] = daily_data.loc[
        daily_data.Week < week].groupby(col).Quantity.quantile(0.75) - daily_data.loc[
        daily_data.Week < week].groupby(col).Quantity.quantile(0.25)
    daily_data = daily_data.reset_index()
daily_data.head()
# Out:
#    Quarter  Month  Weekday StockCode  Year  Week       Date  Dayofyear  Day  \
# 0        4     12        2     10002  2010    48 2010-12-01        335    1
# 1        4     12        2     10125  2010    48 2010-12-01        335    1
# 2        4     12        2     10133  2010    48 2010-12-01        335    1
# 3        4     12        2     16014  2010    48 2010-12-01        335    1
# 4        4     12        2     16016  2010    48 2010-12-01        335    1
#
#    Quantity  ...  WeekdayQuantity_mean_median_diff WeekdayQuantity_IQR  \
# 0  4.094345  ...                         -0.240451             1.89712
# 1  0.693147  ...                         -0.240451             1.89712
# 2  1.609438  ...                         -0.240451             1.89712
# 3  2.302585  ...                         -0.240451             1.89712
# 4  2.302585  ...                         -0.240451             1.89712
#
#    MonthQuantity_mean  MonthQuantity_median  MonthQuantity_mean_median_diff  \
# 0            1.970972              2.079442                       -0.108469
# 1            1.970972              2.079442                       -0.108469
# 2            1.970972              2.079442                       -0.108469
# 3            1.970972              2.079442                       -0.108469
# 4            1.970972              2.079442                       -0.108469
#
#    MonthQuantity_IQR  QuarterQuantity_mean  QuarterQuantity_median  \
# 0           1.845827              2.025252                2.079442
# 1           1.845827              2.025252                2.079442
# 2           1.845827              2.025252                2.079442
# 3           1.845827              2.025252                2.079442
# 4           1.845827              2.025252                2.079442
#
#    QuarterQuantity_mean_median_diff  QuarterQuantity_IQR
# 0                         -0.054189              1.89712
# 1                         -0.054189              1.89712
# 2                         -0.054189              1.89712
# 3                         -0.054189              1.89712
# 4                         -0.054189              1.89712
#
# [5 rows x 30 columns]

# %%
to_group = ["StockCode", "PreChristmas"]
daily_data = daily_data.set_index(to_group)
daily_data["PreChristmasMeanQuantity"] = daily_data.loc[
    daily_data.Week < week].groupby(to_group).Quantity.mean().apply(lambda l: np.round(l, 1))
daily_data["PreChristmasMedianQuantity"] = daily_data.loc[
    daily_data.Week < week].groupby(to_group).Quantity.median().apply(lambda l: np.round(l, 1))
daily_data["PreChristmasStdQuantity"] = daily_data.loc[
    daily_data.Week < week].groupby(to_group).Quantity.std().apply(lambda l: np.round(l, 1))
daily_data = daily_data.reset_index()

# %% [markdown]
# **Lag-Features:**

# %%
for delta in range(1,4):
    to_group = ["Week","Weekday","ProductType"]
    daily_data = daily_data.set_index(to_group)
        
    daily_data["QuantityProducttypeWeekWeekdayLag_" + str(delta) + "_median"] = daily_data.groupby(
        to_group).Quantity.median().apply(lambda l: np.round(l,1)).shift(delta)
    
    daily_data = daily_data.reset_index()
    daily_data.loc[daily_data.Week >= (week+delta),
                   "QuantityProductTypeWeekWeekdayLag_" + str(delta) + "_median"] = np.nan

# %%
data["ProductType"] = data.StockCode.map(products.cluster)

# %%
daily_data["TransactionsPerProductType"] = daily_data.ProductType.map(data.loc[data.Week < week].groupby("ProductType").InvoiceNo.nunique())

# %% [markdown]
# ### About countries and customers

# %%
delta = 1
to_group = ["Week", "Weekday", "ProductType"]
daily_data = daily_data.set_index(to_group)
daily_data["DummyWeekWeekdayAttraction"] = data.groupby(to_group).CustomerID.nunique()
daily_data["DummyWeekWeekdayMeanUnitPrice"] = data.groupby(to_group).UnitPrice.mean().apply(lambda l: np.round(l, 2))

daily_data["WeekWeekdayAttraction_Lag1"] = daily_data["DummyWeekWeekdayAttraction"].shift(1)
daily_data["WeekWeekdayMeanUnitPrice_Lag1"] = daily_data["DummyWeekWeekdayMeanUnitPrice"].shift(1)

daily_data = daily_data.reset_index()
daily_data.loc[daily_data.Week >= (week + delta), "WeekWeekdayAttraction_Lag1"] = np.nan
daily_data.loc[daily_data.Week >= (week + delta), "WeekWeekdayMeanUnitPrice_Lag1"] = np.nan
daily_data = daily_data.drop(["DummyWeekWeekdayAttraction", "DummyWeekWeekdayMeanUnitPrice"], axis=1)

# %%
daily_data["TransactionsPerStockCode"] = daily_data.StockCode.map(
    data.loc[data.Week < week].groupby("StockCode").InvoiceNo.nunique())

# %%
daily_data.head()

# %%
daily_data["CustomersPerWeekday"] = daily_data.Month.map(
    data.loc[data.Week < week].groupby("Weekday").CustomerID.nunique())

# %%
X = daily_data.drop(["Quantity", "Revenue", "Date", "Year"], axis=1)
y = daily_data.Quantity
params = CatHyperparameter()

model = Catmodel("new_features_1", params)
model.set_data(X,y, week)
model.learn(plot=True)
# Out:
# MetricVisualizer(layout=Layout(align_self='stretch', height='500px'))
# new_features_1, early-stopped model tree count 672

# %%
model.score()
# Out:
# 0.47325820835331966

# %%
model.show_importances(kind=None)

# %%
model.show_val_results();
# Out:
# Median absolute error: 0.5789819720722014

# %%
np.mean(np.abs(np.exp(model.results.prediction) - np.exp(model.results.Quantity)))
# Out:
# 7.583517385598624

# %%
np.median(np.abs(np.exp(model.results.prediction) - np.exp(model.results.Quantity)))
# Out:
# 3.948260962485623

# %%
search = Hypertuner(model)
#search.learn()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[222], line 1
# ----> 1 search = Hypertuner(model)
#
# NameError: name 'Hypertuner' is not defined

# %%
#model = search.retrain_catmodel()
#print(model.score())

# %%
#model.show_importances(kind=None)
